# %%
# %pip install wbdata
from __future__ import annotations
import time
from functools import lru_cache
from typing import Literal
import wbdata
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
# Out:
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# Key '-7869237558197817386' not in persistent cache.
# Key '3634365075836340668' not in persistent cache.
# Key '-1142456658633905499' not in persistent cache.
# Key '193863312538809575' not in persistent cache.
# Key '-3273135024518527002' not in persistent cache.
# Key '-2764010352207469163' not in persistent cache.
# Key '-520942128631795324' not in persistent cache.
# Key '6861101087125357541' not in persistent cache.
# Key '2413998115169389017' not in persistent cache.
# Key '-1276293140784380809' not in persistent cache.
# Key '9009063756285275635' not in persistent cache.
# Key '-2228319546922621886' not in persistent cache.
# Key '8057037350147034558' not in persistent cache.
# Key '-5755279321009594442' not in persistent cache.
# Key '4530077576060062002' not in persistent cache.
# Key '-6707305727147835519' not in persistent cache.
# Key '-172163640147105776' not in persistent cache.
# Key '1864625174692468514' not in persistent cache.
# Key '2027956656559265784' not in persistent cache.
# Key '-8755597932167359398' not in persistent cache.
# Key '-856513623767167914' not in persistent cache.
# Key '-2614361005532745119' not in persistent cache.
# Key '-6115991482207248426' not in persistent cache.
# Key '-5498831285859178817' not in persistent cache.
# Key '-4077274613305113278' not in persistent cache.
# Key '-5963461004535361382' not in persistent cache.
# Key '-6012206593506961778' not in persistent cache.
# Key '1698216935613963187' not in persistent cache.
# Key '582859047608924840' not in persistent cache.
# Key '746190529475722110' not in persistent cache.
# Key '-7415196647164173062' not in persistent cache.
# Key '4265260044023606379' not in persistent cache.
# Key '-3896127132616288793' not in persistent cache.
# Key '3313233637885365302' not in persistent cache.
# Key '2802346436251238220' not in persistent cache.
# Key '4839135251090812510' not in persistent cache.
# Key '-6398248052117085011' not in persistent cache.
# Key '-3133415950118526705' not in persistent cache.
# Key '9164025741266032907' not in persistent cache.
# Key '7406178359500455702' not in persistent cache.
# Key '-3141481405808904430' not in persistent cache.
# Key '4521708079174022004' not in persistent cache.
# Key '5943264751728087543' not in persistent cache.
# Key '-5991186849065162287' not in persistent cache.
# Key '962424964053563980' not in persistent cache.
# Key '-2727866291900205846' not in persistent cache.
# Key '7557490605169450598' not in persistent cache.
# Key '-3679892698038446923' not in persistent cache.
# Key '6605464199031209521' not in persistent cache.
# Key '-7206852472125419479' not in persistent cache.
# Key '-8322210360130457826' not in persistent cache.
# Key '-8158878878263660556' not in persistent cache.
# Key '-1623736791262930813' not in persistent cache.
# Key '413052023576643477' not in persistent cache.
# Key '7622412794078297572' not in persistent cache.
# Key '8239572990426367181' not in persistent cache.
# Key '4737942513751863874' not in persistent cache.
# Key '-4065934156648570156' not in persistent cache.
# Key '-7567564633323073463' not in persistent cache.
# Key '-6950404436975003854' not in persistent cache.
# Key '1517181524213918510' not in persistent cache.
# Key '-2397852306040909973' not in persistent cache.
# Key '4555759507077816294' not in persistent cache.
# Key '865468251124046468' not in persistent cache.
# Key '-7295918925515848704' not in persistent cache.
# Key '-86558155014194609' not in persistent cache.
# Key '-8247945331654089781' not in persistent cache.
# Key '3432511359533689660' not in persistent cache.
# Key '-4728875817106205512' not in persistent cache.
# Key '2480484953395448583' not in persistent cache.
# Key '1969597751761321501' not in persistent cache.
# Key '4006386566600895791' not in persistent cache.
# Key '-7230996736607001730' not in persistent cache.
# Key '7434550150466251367' not in persistent cache.
# Key '8331277056776116188' not in persistent cache.
# Key '6573429675010538983' not in persistent cache.
# Key '-3974230090298821149' not in persistent cache.
# Key '3688959394684105285' not in persistent cache.
# Key '5110516067238170824' not in persistent cache.
# Key '-1555372397615346471' not in persistent cache.
# Key '-5982852119235693980' not in persistent cache.
# Key '433963333610742092' not in persistent cache.
# Key '-3721422659789916998' not in persistent cache.
# Key '8443425361698612630' not in persistent cache.
# Key '8924581270333419605' not in persistent cache.
# Key '-1383567126161199666' not in persistent cache.
# Key '6182038894576299498' not in persistent cache.
# Key '-2247134028022279856' not in persistent cache.
# Key '-3879536488313837942' not in persistent cache.
# Key '-2552291133534337431' not in persistent cache.
# Key '-338643256471918470' not in persistent cache.
# Key '-6374384383274188721' not in persistent cache.
# Key '-392608455792541670' not in persistent cache.
# Key '2979314771434300223' not in persistent cache.
# Key '1981113304000608066' not in persistent cache.
# Key '-1215969334882315231' not in persistent cache.
# Key '8553997929880501578' not in persistent cache.
# Key '5491212230921888467' not in persistent cache.
# Key '-8006244071312127854' not in persistent cache.
# Key '-2238376754346321816' not in persistent cache.
# Key '-545154468295084545' not in persistent cache.
# Key '6034432230089866260' not in persistent cache.
# Key '-5764103438729742941' not in persistent cache.
# Key '-8700303076149533767' not in persistent cache.
# Key '5229675961162549569' not in persistent cache.
# Key '1622637148247724728' not in persistent cache.
# Key '-1142456658633905499' not in persistent cache.
# Key '-7869237558197817386' not in persistent cache.
# Key '40320524461909118' not in persistent cache.
# Key '3655275157388164156' not in persistent cache.
# Key '-2989139353255660807' not in persistent cache.
# Key '-7694862058646661770' not in persistent cache.
# Key '-1789334835467555461' not in persistent cache.
# Key '3634365075836340668' not in persistent cache.
# Key '4888365609083148439' not in persistent cache.
# Key '4830939173085977947' not in persistent cache.
# Key '7040255841890914842' not in persistent cache.
# Key '-3113195802427796956' not in persistent cache.
# Key '-2003840146285522455' not in persistent cache.
# Key '5812001090841141551' not in persistent cache.
# Key '-4464401771267139231' not in persistent cache.
# Key '-7860101696486792953' not in persistent cache.
# Key '508265847832129780' not in persistent cache.
# Key '-1454084165356061900' not in persistent cache.
# Key '-824649088708891001' not in persistent cache.
# Key '-8687434605451228193' not in persistent cache.
# Key '-1678491019334499792' not in persistent cache.
# Key '-6451743866960850339' not in persistent cache.
# Key '7209915757124585157' not in persistent cache.
# Key '6759340781689480517' not in persistent cache.
# Key '5087305247336297445' not in persistent cache.
# Key '-5167907483908674854' not in persistent cache.
# Key '5304606123674888219' not in persistent cache.
# Key '-428551723237285246' not in persistent cache.
# Key '4358564950802216192' not in persistent cache.
# Key '-1286631631745385890' not in persistent cache.
# Key '-4115735903414882703' not in persistent cache.
# Key '-384822901087690383' not in persistent cache.
# Key '-4062200600097939015' not in persistent cache.
# Key '991465521562536956' not in persistent cache.
# Key '-3729971021239788485' not in persistent cache.
# Key '3731047377712516239' not in persistent cache.
# Key '6788862071407931465' not in persistent cache.
# Key '-8337310810817956777' not in persistent cache.
# Key '-4305551956029183408' not in persistent cache.
# Key '-6852708964481506857' not in persistent cache.
# Key '-7249403411256799880' not in persistent cache.
# Key '-914747577867535499' not in persistent cache.
# Key '6515266203642254166' not in persistent cache.
# Key '-17694748900008285' not in persistent cache.
# Key '5402594208144023038' not in persistent cache.
# Key '7857127765176347257' not in persistent cache.
# Key '-8395255114523508976' not in persistent cache.
# Key '1677951096822780691' not in persistent cache.
# Key '-4694674842690283640' not in persistent cache.
# Key '6223440238431378011' not in persistent cache.
# Key '-7599870694184267459' not in persistent cache.
# Key '7195372192608416569' not in persistent cache.
# Key '9105092920033347101' not in persistent cache.
# Key '7477409499890083270' not in persistent cache.
# Key '-1686258280632460005' not in persistent cache.
# Key '6656976841464124765' not in persistent cache.
# Key '6840860284805428300' not in persistent cache.
# Key '6435440384279687165' not in persistent cache.
# Key '-8849610091274689257' not in persistent cache.
# Key '8374172080442468707' not in persistent cache.
# Key '-9090488732276392915' not in persistent cache.
# Key '3802683175796405384' not in persistent cache.
# Key '-840647029996183462' not in persistent cache.
# Key '-6484905733897228240' not in persistent cache.
# Key '-1634857520574922975' not in persistent cache.
# Key '7020191679245314404' not in persistent cache.
# Key '2279810283478990453' not in persistent cache.
# Key '-5372664891786870135' not in persistent cache.
# Key '-8271799246270269865' not in persistent cache.
# Key '-1318043895119682313' not in persistent cache.
# Key '327954757130541547' not in persistent cache.
# Key '6515523730090548112' not in persistent cache.
# Key '5876235181960230656' not in persistent cache.
# Key '3571484205181743640' not in persistent cache.
# Key '3509813331085850108' not in persistent cache.
# Key '-4884268623977764784' not in persistent cache.
# Key '-1470722761864482108' not in persistent cache.
# Key '-7869237558197817386' not in persistent cache.
# Key '3743443182069378632' not in persistent cache.
# Key '-2498672659013677970' not in persistent cache.
# Key '5215661631028907789' not in persistent cache.
# Key '5497385778577627457' not in persistent cache.
# Key '2817516198902503290' not in persistent cache.
# Key '7024714396002950607' not in persistent cache.
# Key '2834404431329633866' not in persistent cache.
# Key '5327401708165775218' not in persistent cache.
# Key '-4155447960457784892' not in persistent cache.
# Key '6136940651857868513' not in persistent cache.
# Key '-7316492781299397872' not in persistent cache.
# Key '-383596647018375959' not in persistent cache.
# Key '3665116011125521825' not in persistent cache.
# Key '1823798167524260613' not in persistent cache.
# Key '621622847979516804' not in persistent cache.
# Key '1058387020172952793' not in persistent cache.
# Key '-1010747401841147626' not in persistent cache.
# Key '2315368903480077855' not in persistent cache.
# Key '-957205558306633525' not in persistent cache.
# Key '-181116399288027920' not in persistent cache.
# Key '3155146373805679404' not in persistent cache.
# Key '4229658509322204412' not in persistent cache.
# Key '4285154243342610827' not in persistent cache.
# Key '-1740729388110867132' not in persistent cache.
# Key '-1061259421017677264' not in persistent cache.
# Key '2928626615800861424' not in persistent cache.
# Key '5649327105094188233' not in persistent cache.
# Key '1629236146459397605' not in persistent cache.
# Key '4478182421119709294' not in persistent cache.
# Key '-4337804132561303936' not in persistent cache.
# Key '8842203026068737125' not in persistent cache.
# Key '-7249403411256799880' not in persistent cache.
# Key '-914747577867535499' not in persistent cache.
# Key '6515266203642254166' not in persistent cache.
# Key '-17694748900008285' not in persistent cache.
# Key '5402594208144023038' not in persistent cache.
# Key '7857127765176347257' not in persistent cache.
# Key '-8395255114523508976' not in persistent cache.
# Key '1677951096822780691' not in persistent cache.
# Key '-4694674842690283640' not in persistent cache.
# Key '6223440238431378011' not in persistent cache.
# Key '-7599870694184267459' not in persistent cache.
# Key '7195372192608416569' not in persistent cache.
# Key '9105092920033347101' not in persistent cache.
# Key '7477409499890083270' not in persistent cache.
# Key '-1686258280632460005' not in persistent cache.
# Key '6656976841464124765' not in persistent cache.
# Key '6840860284805428300' not in persistent cache.
# Key '6435440384279687165' not in persistent cache.
# Key '-8849610091274689257' not in persistent cache.
# Key '8374172080442468707' not in persistent cache.
# Key '-9090488732276392915' not in persistent cache.
# Key '3802683175796405384' not in persistent cache.
# Key '-840647029996183462' not in persistent cache.
# Key '-6484905733897228240' not in persistent cache.
# Key '-1634857520574922975' not in persistent cache.
# Key '7020191679245314404' not in persistent cache.
# Key '2279810283478990453' not in persistent cache.
# Key '-5372664891786870135' not in persistent cache.
# Key '-8271799246270269865' not in persistent cache.
# Key '-1318043895119682313' not in persistent cache.
# Key '327954757130541547' not in persistent cache.
# Key '6515523730090548112' not in persistent cache.
# Key '5876235181960230656' not in persistent cache.
# Key '3571484205181743640' not in persistent cache.
# Key '3508582181296792347' not in persistent cache.
# Key '6859538279455420417' not in persistent cache.
# Key '5921256818088520350' not in persistent cache.
# Key '9170917769042241182' not in persistent cache.
# Key '2225539774172834544' not in persistent cache.
# Key '-4557532088790618132' not in persistent cache.
# Key '-1142456658633905499' not in persistent cache.
# Key '8111000506815739183' not in persistent cache.
# Key '-7869237558197817386' not in persistent cache.
# Key '4108416994538936524' not in persistent cache.
# Key '2545358737410019924' not in persistent cache.
# Key '2095706047558955025' not in persistent cache.
# Key '2054862486405652825' not in persistent cache.
# Key '5655567591110046533' not in persistent cache.
# Key '-2137018385203485318' not in persistent cache.
# Key '-537381838921342049' not in persistent cache.
# Key '2748686549501744526' not in persistent cache.
# Key '-4972122216421339354' not in persistent cache.
# Key '-1040917821278437083' not in persistent cache.
# Key '-279356131421429598' not in persistent cache.
# Key '-5687794138750440107' not in persistent cache.
# Key '1056743576879118253' not in persistent cache.
# Key '-7272169472915557517' not in persistent cache.
# Key '2965383652618977386' not in persistent cache.
# Key '-8928929841349381891' not in persistent cache.

# %% [markdown]
# # 1. Population DataFrames [A]

# %% [markdown]
# ### Helper Functions

# %%
#Helper Functions

Sex = Literal["female", "male", "total"]

AGE_BINS_5Y = [
    "0004","0509","1014","1519","2024","2529","3034","3539",
    "4044","4549","5054","5559","6064","6569","7074","7579","80UP"
]

BIN_TO_RANGE = {
    "0004": (0,4),   "0509": (5,9),   "1014": (10,14), "1519": (15,19),
    "2024": (20,24), "2529": (25,29), "3034": (30,34), "3539": (35,39),
    "4044": (40,44), "4549": (45,49), "5054": (50,54), "5559": (55,59),
    "6064": (60,64), "6569": (65,69), "7074": (70,74), "7579": (75,79),
    "80UP": (80,200),
}

def bins_for_age_range(start_age: int, end_age: int) -> list[str]:
    ''' >>> bins_for_age_range(start_age = 0, end_age = 9)
        return: ['0004', '0509']
        '''
    return [b for b,(lo,hi) in BIN_TO_RANGE.items() if not (hi < start_age or lo > end_age)]

def wb_indicator_5y(age_code: str, sex: str) -> str:
    ''' This helper constructs variable indicator.
    >>> wb_indicator_5y(age_code = '0004', sex = 'female')
    output: "SP.POP.0004.FE"
    '''
    
    sex_code = "FE" if sex == "female" else "MA"
    return f"SP.POP.{age_code}.{sex_code}"

# %% [markdown]
# Below is validation helper functions

# %%
def _validate_years(years: tuple[int, int]) -> None:
    if (not isinstance(years, tuple)) or len(years) != 2:
        raise TypeError("years must be a tuple of (start_year, end_year)")
    y0, y1 = years
    if not (isinstance(y0, int) and isinstance(y1, int)):
        raise TypeError("years must contain integers")
    if y0 > y1:
        raise ValueError("years must satisfy start_year <= end_year")
    if y0 < 1960 or y1 > 2024:
        raise ValueError("years must be between 1960 and 2024, inclusive")


def _validate_area(area: str) -> str:
    if not isinstance(area, str):
        raise TypeError("area must be a string")
    area = area.strip()
    if not area:
        raise ValueError("area must be a non-empty string")
    return area


def _validate_sex(sex: str) -> Sex:
    if not isinstance(sex, str):
        raise TypeError("sex must be a string")
    sex = sex.strip().lower()
    if sex not in ("female", "male", "total"):
        raise ValueError("sex must be 'female', 'male', or 'total'")
    return sex  # type: ignore[return-value]


def _validate_age_range(age_range: tuple[int, int]) -> tuple[int, int]:
    if (not isinstance(age_range, tuple)) or len(age_range) != 2:
        raise TypeError("age_range must be a tuple (low, high)")
    low, high = age_range
    if not (isinstance(low, int) and isinstance(high, int)):
        raise TypeError("age_range bounds must be integers")
    if low < 0 or high < 0:
        raise ValueError("age_range bounds must be non-negative")
    if low > high:
        raise ValueError("age_range must satisfy low <= high")

    # Exact 5-year boundary validation:
    # valid ranges are unions of 5-year bins, so:
    #   low must be multiple of 5
    #   high must be 4 mod 5
    if (low % 5) != 0 or (high % 5) != 4:
        raise ValueError(
            "age_range must align to 5-year bins, e.g. (0,4), (0,9), (5,14), (15,19)"
        )

    # Optional: enforce max bound if your bins top out (e.g., 100+)
    # You can skip this if AGE_BINS_5Y already handles it robustly.
    return low, high

# %% [markdown]
# ### Below is the main population DataFrame function.

# %%
@lru_cache(maxsize=128)
def population_df(years: tuple[int, int], area: str, chunk: int = 4) -> pd.DataFrame:
    """
    Example: india_pop_df = population_df(years=(2018, 2020), area="India")
    Returns a DataFrame with male and female counts of each 5-year age range.
    Please enter a year between 1960 and 2024. 
    """
    _validate_years(years)
    area = _validate_area(area)
    if not isinstance(chunk, int) or chunk <= 0:
        raise ValueError("chunk must be a positive integer")

    # Resolve country id (kept inside cached function; caching avoids repeat lookups too)
    countries = wbdata.get_countries(query=f"^{re.escape(area)}$")
    if not countries:
        raise ValueError(f"No country matched area={area!r}")
    country_id = countries[0]["id"]

    def fetch(sub_bins: list[str]) -> pd.DataFrame:
        indicators: dict[str, str] = {}
        for b in sub_bins:
            indicators[wb_indicator_5y(b, "female")] = f"female_{b}"
            indicators[wb_indicator_5y(b, "male")] = f"male_{b}"

        last_err: Exception | None = None
        for k in range(5):
            try:
                # Note: skip_cache=True means "do not use wbdata's cache".
                # Our lru_cache handles caching at the function level.
                return wbdata.get_dataframe(
                    indicators,
                    country=country_id,
                    parse_dates=True,
                    skip_cache=True,
                )
            except Exception as e:
                last_err = e
                time.sleep(0.5 * (2 ** k))
        assert last_err is not None
        raise last_err

    parts: list[pd.DataFrame] = []
    for i in range(0, len(AGE_BINS_5Y), chunk):
        parts.append(fetch(AGE_BINS_5Y[i : i + chunk]))

    df = pd.concat(parts, axis=1)

    # Ensure datetime-like index
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index.astype(str), errors="coerce")

    y0, y1 = years
    df = df[(df.index.year >= y0) & (df.index.year <= y1)]

    # Consistent column order: female bins then male bins
    df = df[[f"female_{b}" for b in AGE_BINS_5Y] + [f"male_{b}" for b in AGE_BINS_5Y]]

    df.index = df.index.year
    return df

# %% [markdown]
# ## Example usage: India, Pakistan, Bangladesh

# %%
india_pop_df = population_df(
    years=(2018, 2020),
    area="India"
)
india_pop_df

# %%
pakistan_pop_df = population_df(
    years=(2018, 2020),
    area="Pakistan"
)
pakistan_pop_df

# %%
bangladesh_pop_df = population_df(
    years=(2018, 2020),
    area="Bangladesh"
)
bangladesh_pop_df

# %% [markdown]
# # 2. Population Statistics [A]

# %% [markdown]
# This functio answers the question: In [year] how many [people/males/females] aged [low] to [high] were living in [the world/region/country]?

# %%
def population_stats(
    year: int,
    sex: str,
    age_range: tuple[int, int],
    area: str,
) -> int:
    """
    Returns the population count as an integer.
    For variable sex, please enter 'female, 'male', or 'total'.
    Age range should also follow five the head and tail of 5-year range
    ex. 0-4, 5-9, 5-14, 15-29 

    Example:
    pakistan_pop_stats = population_stats(year= 2000, 
                     sex= 'total', 
                     age_range= (15, 29), 
                     area= 'Pakistan')
    output: 41045700
    """
    if not isinstance(year, int):
        raise TypeError("year must be an int")
    if year < 1960 or year > 2024:
        raise ValueError("year must be between 1960 and 2024")

    sex_v = _validate_sex(sex)
    low, high = _validate_age_range(age_range)
    area = _validate_area(area)

    df = population_df((year, year), area)
    if df.empty:
        raise ValueError(f"No data returned for {area!r} in {year}")

    row = df.iloc[0]
    bins = bins_for_age_range(low, high)

    if sex_v == "female":
        count = sum(row[f"female_{b}"] for b in bins)
    elif sex_v == "male":
        count = sum(row[f"male_{b}"] for b in bins)
    else:  # total
        count = sum(row[f"female_{b}"] + row[f"male_{b}"] for b in bins)

    # Be robust to floats/NaNs coming back from wbdata
    if pd.isna(count):
        raise ValueError("Population count is NaN (missing data for one or more bins)")
    return int(count)


def format_population_stats_sentence(
    year: int,
    sex: str,
    age_range: tuple[int, int],
    area: str,
) -> str:
    """
    This returns the wrapper that produces the sentence: 
    In [year] how many [people/males/females] aged [low] to [high] 
    were living in [the world/region/country]?

    """
    sex_v = _validate_sex(sex)
    low, high = _validate_age_range(age_range)
    area = _validate_area(area)

    count = population_stats(year, sex_v, (low, high), area)

    who = {"female": "females", "male": "males", "total": "people"}[sex_v]
    return f"In {year}, there were {count:,} {who} aged {low} to {high} living in {area}."

# %%
india_pop_stats = format_population_stats_sentence(year= 2000, 
                     sex= 'female', 
                     age_range= (15, 29), 
                     area= 'India')
india_pop_stats

# %%
pakistan_pop_stats = format_population_stats_sentence(year= 2000, 
                     sex= 'total', 
                     age_range= (15, 29), 
                     area= 'Pakistan')
pakistan_pop_stats

# %% [markdown]
# # Studying India v.s Bangladesh v.s Pakistan Pre- and Post- Liberation War

# %% [markdown]
# ## Population Growth Rate
# First we want to visualize population growth rate

# %%
def population_growth_rate(years,country):
    
    def country_id(country):
        single_country = wbdata.get_countries(query=f"^{re.escape(country)}$")
        return single_country[0]["id"]

    country_id = country_id(country)
    indicators = {"SP.POP.GROW" : "Population growth (annual %)"}

    country_df = wbdata.get_dataframe(indicators, country = country_id, parse_dates = True)

    start, end = years
    growth_adjusted = country_df[(country_df.index.year >= start) & (country_df.index.year <= end)]

    return growth_adjusted.rename(columns = lambda c: country if c == growth_adjusted.columns[0] else c)
    

rate_BGD = population_growth_rate([1961, 1980], "Bangladesh")
rate_IND = population_growth_rate([1961, 1980], "India")
rate_PAK = population_growth_rate([1961, 1980], "Pakistan")

# %%
pop_growth_rate = rate_BGD.join([rate_IND, rate_PAK])
pop_growth_rate.head()

# %%
plt.plot(pop_growth_rate, label = pop_growth_rate.columns )
plt.ylabel("Annual %")
plt.xlabel("Date")
plt.title("Population growth (annual %)")
plt.legend()

# %% [markdown]
# ### Population growth rate = Birth rate−Death rate+Net migration
#
# The graph clearly shows a major dip around 1971 for Bangladesh, for almost a 1.5% decrease, where many either died or fled to India, as India was located in between the now Bangladesh and Pakistan. Later we will examine both fertility and mortality rate.

# %% [markdown]
# We also want to examine rural v.s urban population growth to grasp if there was uneven impact of the war to urban and rural population.
# Below we visualize the comparison or rural v.s urban population growth.

# %%
def pop_growth(years,country, indicator):
    
    def country_id(country):
        single_country = wbdata.get_countries(query=f"^{re.escape(country)}$")
        return single_country[0]["id"]

    country_id = country_id(country)


    country_df = wbdata.get_dataframe(indicator, country = country_id, parse_dates = True)

    start, end = years
    growth_adjusted = country_df[(country_df.index.year >= start) & (country_df.index.year <= end)]

    return growth_adjusted.rename(columns = lambda c: country if c == growth_adjusted.columns[0] else c)
    
rural_BGD = pop_growth([1961, 1980], "Bangladesh", {"SP.RUR.TOTL.ZG": "Rural population growth (annual %)"})
rural_IND = pop_growth([1961, 1980], "India",  {"SP.RUR.TOTL.ZG": "Rural population growth (annual %)"})
rural_PAK = pop_growth([1961, 1980], "Pakistan",  {"SP.RUR.TOTL.ZG": "Rural population growth (annual %)"})
# Out:
# Key '7261572386511554378' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7350172603390430439' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4856887768505429189' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '463820484608962707' not in persistent cache.

# %%
rural_pop_growth = rural_BGD.join([rural_IND, rural_PAK])
plt.plot(rural_pop_growth, label = rural_pop_growth.columns)
plt.ylabel("Annual %")
plt.xlabel("Date")
plt.title("Rural population growth (annual %)")
plt.legend()

# %%
urban_BGD = pop_growth([1961, 1980], "Bangladesh", {'SP.URB.GROW':'Urban population growth (annual %)'})
urban_IND = pop_growth([1961, 1980], "India",  {'SP.URB.GROW':'Urban population growth (annual %)'})
urban_PAK = pop_growth([1961, 1980], "Pakistan",  {'SP.URB.GROW':'Urban population growth (annual %)'})
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-422278417504316151' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2856480084681021036' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6553079530030680891' not in persistent cache.

# %%
urban_pop = urban_BGD.join([urban_IND, urban_PAK])
plt.plot(urban_pop, label = urban_pop.columns)
plt.ylabel("Annual %")
plt.xlabel("Date")
plt.title("Urban Population growth (annual %)")
plt.legend()

# %% [markdown]
# From these two graphs, the population growth curve for Bangladesh and Pakistan looks very similar with about the same magnitude of decrease aroung 1971. However, we discovered a significant distinction between urban population and rural population in Bangladesh. Rural population decreased by 1.5%, but urban population drastically increased by 6%, which indicates fast urbanization.

# %% [markdown]
# Below we examine this change more closely by only focusing on Bangladesh.
