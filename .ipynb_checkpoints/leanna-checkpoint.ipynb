# %%
# %pip install wbdata

import wbdata
# Out:
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# Key '-6599433773086753518' not in persistent cache.
# Key '8157019044669028272' not in persistent cache.
# Key '-3080364258538869249' not in persistent cache.
# Key '-1658807585984803710' not in persistent cache.
# Key '-9101554692587549736' not in persistent cache.
# Key '5654898125168232054' not in persistent cache.
# Key '-2506489051471663118' not in persistent cache.
# Key '4702871719029990977' not in persistent cache.
# Key '5320031915378060586' not in persistent cache.
# Key '1175911944943018421' not in persistent cache.
# Key '-2779003517591688392' not in persistent cache.
# Key '-8810173174360930797' not in persistent cache.
# Key '5295324412877635829' not in persistent cache.
# Key '-49581493241360245' not in persistent cache.
# Key '-2611825351212933380' not in persistent cache.
# Key '-3576541267328332801' not in persistent cache.
# Key '4086648217654593633' not in persistent cache.
# Key '-4074738958985301539' not in persistent cache.
# Key '3134621811516352556' not in persistent cache.
# Key '-555669444437417270' not in persistent cache.
# Key '-392337962570620000' not in persistent cache.
# Key '1029218709983445539' not in persistent cache.
# Key '-3765856490968811790' not in persistent cache.
# Key '8342924421136481303' not in persistent cache.
# Key '7227566533131442956' not in persistent cache.
# Key '7390898014998240226' not in persistent cache.
# Key '-7791013956712753084' not in persistent cache.
# Key '-7536776544163427121' not in persistent cache.
# Key '2063764532029141846' not in persistent cache.
# Key '-8365762507724468687' not in persistent cache.
# Key '3092063173863609242' not in persistent cache.
# Key '-2252842732255386832' not in persistent cache.
# Key '-9213443973211328095' not in persistent cache.
# Key '1266226782292497437' not in persistent cache.
# Key '-2514970404343801082' not in persistent cache.
# Key '7770386492725855362' not in persistent cache.
# Key '-3466996810482042159' not in persistent cache.
# Key '-7157288066435811985' not in persistent cache.
# Key '52072704065842110' not in persistent cache.
# Key '1473629376619907649' not in persistent cache.
# Key '-5969117729982838377' not in persistent cache.
# Key '8787335087772943413' not in persistent cache.
# Key '625947911133048241' not in persistent cache.
# Key '7835308681634702336' not in persistent cache.
# Key '4054111494998403817' not in persistent cache.
# Key '4308348907547729780' not in persistent cache.
# Key '8660564564148332375' not in persistent cache.
# Key '-1768962475605278158' not in persistent cache.
# Key '-8757880867726751845' not in persistent cache.
# Key '4343957299863803697' not in persistent cache.
# Key '-2616643941092137566' not in persistent cache.
# Key '7863026814411687966' not in persistent cache.
# Key '4081829627775389447' not in persistent cache.
# Key '2966471739770351100' not in persistent cache.
# Key '3129803221637148370' not in persistent cache.
# Key '-560488034316621456' not in persistent cache.
# Key '6648872736185032639' not in persistent cache.
# Key '8070429408739098178' not in persistent cache.
# Key '627682302136352152' not in persistent cache.
# Key '-3062608953817417674' not in persistent cache.
# Key '7222747943252238770' not in persistent cache.
# Key '-4014635359955658751' not in persistent cache.
# Key '3648554125027267683' not in persistent cache.
# Key '-7541595134042631307' not in persistent cache.
# Key '1587003998864604903' not in persistent cache.
# Key '-8842523040889005630' not in persistent cache.
# Key '2615302640699072299' not in persistent cache.
# Key '-2729603265419923775' not in persistent cache.
# Key '8756539567333686578' not in persistent cache.
# Key '-6256563039506896331' not in persistent cache.
# Key '-2991730937508338025' not in persistent cache.
# Key '7293625959561318419' not in persistent cache.
# Key '-3943757343646579102' not in persistent cache.
# Key '-7634048599600348928' not in persistent cache.
# Key '-424687829098694833' not in persistent cache.
# Key '996868843455370706' not in persistent cache.
# Key '-6445878263147375320' not in persistent cache.
# Key '8310574554608406470' not in persistent cache.
# Key '149187377968511298' not in persistent cache.
# Key '7358548148470165393' not in persistent cache.
# Key '7975708344818235002' not in persistent cache.
# Key '3831588374383192837' not in persistent cache.
# Key '7044011181881257533' not in persistent cache.
# Key '-3385515857872353000' not in persistent cache.
# Key '8072309823715724929' not in persistent cache.
# Key '2727403917596728855' not in persistent cache.
# Key '-4233197323359212408' not in persistent cache.
# Key '6246473432144613124' not in persistent cache.
# Key '2465276245508314605' not in persistent cache.
# Key '-5696110931131580567' not in persistent cache.
# Key '1513249839370073528' not in persistent cache.
# Key '-2177041416583696298' not in persistent cache.
# Key '5032319353917957797' not in persistent cache.
# Key '6453876026472023336' not in persistent cache.
# Key '-988871080130722690' not in persistent cache.
# Key '-4679162336084492516' not in persistent cache.
# Key '5606194560985163928' not in persistent cache.
# Key '-5631188742222733593' not in persistent cache.
# Key '-5014028545874663984' not in persistent cache.
# Key '-9158148516309706149' not in persistent cache.
# Key '6626140328442562008' not in persistent cache.
# Key '-1277309215599170063' not in persistent cache.
# Key '881998288795475796' not in persistent cache.
# Key '-2153712153135698293' not in persistent cache.
# Key '-8184881809904940698' not in persistent cache.
# Key '5920615777333625928' not in persistent cache.
# Key '575709871214629854' not in persistent cache.
# Key '-1986533986756943281' not in persistent cache.
# Key '-2951249902872342702' not in persistent cache.
# Key '4711939582110583732' not in persistent cache.
# Key '-3449447594529311440' not in persistent cache.
# Key '-638444207012025473' not in persistent cache.
# Key '69621920018572829' not in persistent cache.
# Key '-4165403981098998029' not in persistent cache.
# Key '1654510074439435638' not in persistent cache.
# Key '-3140565126512821691' not in persistent cache.
# Key '4569858402608103274' not in persistent cache.
# Key '7852857897587433055' not in persistent cache.
# Key '3617831996469862197' not in persistent cache.
# Key '-7165722592256762985' not in persistent cache.
# Key '7136901511017746466' not in persistent cache.

# %%
# %pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /srv/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /srv/conda/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def country_id(country):
    single_country = wbdata.get_countries(query = country)
    return single_country[0]["id"]

country_id("Bangladesh")
# Out:
# 'BGD'

# %%
#def population(year, age, gender):
 #   if year<1960:
  #      return "Please select a year later than 1960"
  #  else:
   #     gender [:2] 
   #     variable_female = {"SP.POP.TOTL

# %%
variable_labels_female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
variable_labels_male = {"SP.POP.TOTL.MA.IN" : "Population, male"}

female_chart_ind = wbdata.get_dataframe(variable_labels_female, country="IND",parse_dates=True)
male_chart_ind = wbdata.get_dataframe(variable_labels_male, country="IND",parse_dates=True)



# Print a few years' data
table_joined = female_chart_ind.join(male_chart_ind)
ind_gen = table_joined.plot()
ind_gen.set_title("India's population by gender (1960-Present)")
# Out:
# Text(0.5, 1.0, "India's population by gender (1960-Present)")

# %%
variable_labels_female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
variable_labels_male = {"SP.POP.TOTL.MA.IN" : "Population, male"}

female_chart_pak = wbdata.get_dataframe(variable_labels_female, country="PAK",parse_dates=True)
male_chart_pak = wbdata.get_dataframe(variable_labels_male, country="PAK",parse_dates=True)



# Print a few years' data
table_joined = female_chart_ind.join(male_chart_ind)
pak_gen = table_joined.plot()
pak_gen.set_title("Pakistan's population by gender (1960-Present)")
# Out:
# Text(0.5, 1.0, "Pakistan's population by gender (1960-Present)")

# %%
variable_labels_female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
variable_labels_male = {"SP.POP.TOTL.MA.IN" : "Population, male"}

female_chart_pak = wbdata.get_dataframe(variable_labels_female, country="BGD",parse_dates=True)
male_chart_pak = wbdata.get_dataframe(variable_labels_male, country="BGD",parse_dates=True)



# Print a few years' data
table_joined = female_chart_ind.join(male_chart_ind)
bgd_gen = table_joined.plot()
bgd_gen.set_title("Bangladesh's population by gender (1960-Present)")
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-8450499298153232863' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3965075118787076348' not in persistent cache.
# Text(0.5, 1.0, "Bangladesh's population by gender (1960-Present)")

# %%
female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
male = {"SP.POP.TOTL.MA.IN" : "Population, male"}

#creating dataframe of populations by country, organized by gender
def get_genders_df(country, gender):
    
    def country_id(country):
        single_country = wbdata.get_countries(query = country)
        return single_country[0]["id"]
        
    country_id = country_id(country) 

    female_df = wbdata.get_dataframe(variable_labels_female, country=country_id,parse_dates=True)
    male_df = wbdata.get_dataframe(variable_labels_male, country=country_id,parse_dates=True)
    if gender == "female": 
        return female_df 
    if gender == "male":
        return male_df 
    if gender == "female and male":
        return female_df.join(male_df)
    else: 
        return "Format gender as 'male', 'female', or 'female and male'"

def population_trend_on_event(country, gender, date):
    gender_df = get_genders_df(country, gender)
    return gender_df.where("date", are.equal_to(date))
    
    
def plot_df(country):
    df = get_gender_df(country)
    plotted = df.plot()
    return plotted.set_title( country + "'s population by gender (1960-Present)")
    
get_genders_df("India", "male")

def population_trend_on_event("India", "male", 2006)
# Out:
#   Cell In[35], line 36
#     def population_trend_on_event("India", "male", 2006)
#                                   ^
# SyntaxError: invalid syntax

# %%
variable_labels_female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
