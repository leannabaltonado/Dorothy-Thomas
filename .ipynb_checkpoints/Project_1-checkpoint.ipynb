# %%
#%pip install wbdata
import wbdata
import numpy as np
import pandas as pd
# Out:
# Key '-4265940834655764446' not in persistent cache.
# Key '4725971338136137976' not in persistent cache.
# Key '1035680082182368150' not in persistent cache.
# Key '8245040852684022245' not in persistent cache.
# Key '83653676044127073' not in persistent cache.
# Key '-6065648706280864931' not in persistent cache.
# Key '-3443306098042845483' not in persistent cache.
# Key '-2546579191732980662' not in persistent cache.
# Key '-1125022519178915123' not in persistent cache.
# Key '2139809582819643183' not in persistent cache.
# Key '-2841182536812009648' not in persistent cache.
# Key '5805255895354952564' not in persistent cache.
# Key '6513322022385550866' not in persistent cache.
# Key '-8668589949325442444' not in persistent cache.
# Key '-8505258467458645174' not in persistent cache.
# Key '-37672506269722810' not in persistent cache.
# Key '-2364021540824030895' not in persistent cache.
# Key '5299167944158895539' not in persistent cache.
# Key '-7066262757031198673' not in persistent cache.
# Key '-722022489889784948' not in persistent cache.
# Key '-4412313745843554774' not in persistent cache.
# Key '2797047024658099321' not in persistent cache.
# Key '-5364340151981795851' not in persistent cache.
# Key '-8865970628656299158' not in persistent cache.
# Key '-1845270637433911582' not in persistent cache.
# Key '6053813670966279902' not in persistent cache.
# Key '7475370343520345441' not in persistent cache.
# Key '-3308184245206279741' not in persistent cache.
# Key '4570448845280238314' not in persistent cache.
# Key '-5229856796262351090' not in persistent cache.
# Key '-8920148052216120916' not in persistent cache.
# Key '-1256958567233194482' not in persistent cache.
# Key '5952402203268459613' not in persistent cache.
# Key '7373958875822525152' not in persistent cache.
# Key '-6353104943806477724' not in persistent cache.
# Key '-5735944747458408115' not in persistent cache.
# Key '345368625061049289' not in persistent cache.
# Key '-4711105892872231777' not in persistent cache.
# Key '-8401397148826001603' not in persistent cache.
# Key '5810321023765979155' not in persistent cache.
# Key '2047291230110452111' not in persistent cache.
# Key '-1454339246564051196' not in persistent cache.
# Key '5566360744658336380' not in persistent cache.
# Key '-4981299020651023752' not in persistent cache.
# Key '3486286940537898612' not in persistent cache.
# Key '4103447136885968221' not in persistent cache.
# Key '-1669796285491284118' not in persistent cache.
# Key '6976642146675678094' not in persistent cache.
# Key '7684708273706276396' not in persistent cache.
# Key '-7497203698004716914' not in persistent cache.
# Key '-7333872216137919644' not in persistent cache.
# Key '1133713745051002720' not in persistent cache.
# Key '-1192635289503305365' not in persistent cache.
# Key '6470554195479621069' not in persistent cache.
# Key '-5894876505710473143' not in persistent cache.
# Key '449363761430940582' not in persistent cache.
# Key '-3240927494522829244' not in persistent cache.
# Key '3968433275978824851' not in persistent cache.
# Key '-4192953900661070321' not in persistent cache.
# Key '-7694584377335573628' not in persistent cache.
# Key '-673884386113186052' not in persistent cache.
# Key '7225199922287005432' not in persistent cache.
# Key '-5401630095884112517' not in persistent cache.
# Key '-2136797993885554211' not in persistent cache.
# Key '-8589816260508859112' not in persistent cache.
# Key '7102651460292959925' not in persistent cache.
# Key '3412360204339190099' not in persistent cache.
# Key '4029520400687259708' not in persistent cache.
# Key '-7207862902520637813' not in persistent cache.
# Key '-5786306229966572274' not in persistent cache.
# Key '-1066625975886023534' not in persistent cache.
# Key '6596563509096902900' not in persistent cache.
# Key '5631847592981503479' not in persistent cache.
# Key '575373075048222413' not in persistent cache.
# Key '-3114918180905547413' not in persistent cache.
# Key '4094442589596106682' not in persistent cache.
# Key '-4066944587043788490' not in persistent cache.
# Key '3832139721356402994' not in persistent cache.
# Key '-7593904361130761046' not in persistent cache.
# Key '7351209235904287263' not in persistent cache.
# Key '8772765908458352802' not in persistent cache.
# Key '-2010788680268272380' not in persistent cache.
# Key '-4180798384941387918' not in persistent cache.
# Key '8863997430209942422' not in persistent cache.
# Key '5173706174256172596' not in persistent cache.
# Key '-5609848414470452586' not in persistent cache.
# Key '8601869758121528172' not in persistent cache.
# Key '3021069028585267048' not in persistent cache.
# Key '694719994030958963' not in persistent cache.
# Key '3959552096029517269' not in persistent cache.
# Key '-4007521222176208815' not in persistent cache.
# Key '-2061638338019163218' not in persistent cache.
# Key '-5751929593972933044' not in persistent cache.
# Key '1457431176528721051' not in persistent cache.
# Key '-6703956000111174121' not in persistent cache.
# Key '-5807229093801309300' not in persistent cache.
# Key '-3184886485563289852' not in persistent cache.
# Key '9112555205821269760' not in persistent cache.
# Key '-7912632195334216317' not in persistent cache.
# Key '-4647800093335658011' not in persistent cache.
# Key '-2871554206605679697' not in persistent cache.
# Key '9197767675357299419' not in persistent cache.
# Key '2959312731746551215' not in persistent cache.
# Key '-636662840943013681' not in persistent cache.
# Key '8009775591223948531' not in persistent cache.
# Key '8717841718254546833' not in persistent cache.
# Key '-6464070253456446477' not in persistent cache.
# Key '-6300738771589649207' not in persistent cache.
# Key '-4879182099035583668' not in persistent cache.
# Key '-159501844955034928' not in persistent cache.
# Key '7503687640027891506' not in persistent cache.
# Key '6538971723912492085' not in persistent cache.
# Key '1482497205979211019' not in persistent cache.
# Key '-2207794049974558807' not in persistent cache.
# Key '5001566720527095288' not in persistent cache.
# Key '-3159820456112799884' not in persistent cache.
# Key '4739263852287391600' not in persistent cache.
# Key '359249058435084385' not in persistent cache.
# Key '8258333366835275869' not in persistent cache.
# Key '-8766854034320210208' not in persistent cache.
# Key '-1103664549337283774' not in persistent cache.
# Key '3726101197742925655' not in persistent cache.
# Key '-6074204443799663749' not in persistent cache.

# %%
india_df = population_df((2000, 2010), (1, 3), "India")
india_df
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-5366138316769065447' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2101306214770507141' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5108054555731146954' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6529611228285212493' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2799095208359422255' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6580292394995720774' not in persistent cache.
#                male_01   female_01     male_02   female_02     male_03  \
# date
# 2010-01-01  13495545.0  12298938.0  13415841.5  12215921.0  13456025.5
# 2009-01-01  13472670.5  12282255.0  13484389.5  12278052.5  13601170.5
# 2008-01-01  13548239.5  12352226.5  13634321.0  12407041.5  13782866.0
# 2007-01-01  13705075.0  12488959.0  13820419.0  12567362.0  13918835.0
# 2006-01-01  13894405.5  12653374.0  13957326.5  12693488.0  14008123.0
# 2005-01-01  14036289.5  12785347.5  14049018.5  12791509.5  14090686.0
# 2004-01-01  14133068.5  12889388.5  14134137.5  12865285.5  14053390.5
# 2003-01-01  14222743.0  12968494.5  14098552.5  12807316.5  13882771.5
# 2002-01-01  14193578.5  12917390.5  13931333.0  12647920.0  13743147.5
# 2001-01-01  14029296.5  12761370.5  13792863.5  12526431.5  13663218.5
# 2000-01-01  13893766.0  12643394.0  13714110.0  12461060.5  13583483.0
#
#              female_03
# date
# 2010-01-01  12244401.0
# 2009-01-01  12368019.5
# 2008-01-01  12523308.0
# 2007-01-01  12647810.0
# 2006-01-01  12742689.0
# 2005-01-01  12813192.0
# 2004-01-01  12752942.5
# 2003-01-01  12589598.0
# 2002-01-01  12466298.5
# 2001-01-01  12399016.5
# 2000-01-01  12342092.0

# %%
india_pop = population((2000, 2010), 'Female', (0, 3), 'India')
india_pop
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-498979022476263370' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5555453540409544436' not in persistent cache.
# year
# 2010    49203332.5
# 2009    49422844.5
# 2008    49780946.0
# 2007    50294608.0
# 2006    50836337.5
# 2005    51324745.5
# 2004    51598504.0
# 2003    51584271.0
# 2002    51356932.0
# 2001    50978052.0
# 2000    50590984.5
# Name: female_total, dtype: float64

# %%
#population plots
female = {"SP.POP.TOTL.FE.IN" : "Population, female"}
male = {"SP.POP.TOTL.MA.IN" : "Population, male"}

#creating dataframe of populations by country, organized by gender
def get_genders_df(country, gender):
    
    def country_id(country):
        single_country = wbdata.get_countries(query = country)
        return single_country[0]["id"]
        
    country_id = country_id(country) 

    female_df = wbdata.get_dataframe(female, country=country_id,parse_dates=True)
    male_df = wbdata.get_dataframe(male, country=country_id,parse_dates=True)
    if gender == "female": 
        return female_df 
    if gender == "male":
        return male_df 
    if gender == "female and male":
        return female_df.join(male_df)
    else: 
        return "Format gender as 'male', 'female', or 'female and male'"

def population_trend_on_event(country, gender, date):
    gender_df = get_genders_df(country, gender)
    return gender_df.where("date", are.containing(date))
    
    
def plot_df(country):
    df = get_gender_df(country)
    plotted = df.plot()
    return plotted.set_title( country + "'s population by gender (1960-Present)")
    
get_genders_df("India", "male")
# Out:
#             Population, male
# date
# 2024-01-01       748323427.0
# 2023-01-01       741883264.0
# 2022-01-01       735531456.0
# 2021-01-01       729924103.0
# 2020-01-01       724175467.0
# ...                      ...
# 1964-01-01       247474637.0
# 1963-01-01       241706792.0
# 1962-01-01       236052757.0
# 1961-01-01       230447351.0
# 1960-01-01       224897757.0
#
# [65 rows x 1 columns]
