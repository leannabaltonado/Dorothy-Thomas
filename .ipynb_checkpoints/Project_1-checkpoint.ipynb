# %%
# %pip install wbdata
import wbdata
import numpy as np
import pandas as pd
# Out:
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# Key '1020295768998427317' not in persistent cache.
# Key '-5129006613326564687' not in persistent cache.
# Key '-2506664005088545239' not in persistent cache.
# Key '3313250050449888428' not in persistent cache.
# Key '-188380426224614879' not in persistent cache.
# Key '6871087872379094922' not in persistent cache.
# Key '-3715340200311587435' not in persistent cache.
# Key '-1036061891711474287' not in persistent cache.
# Key '6173298878790179808' not in persistent cache.
# Key '2392101692153881289' not in persistent cache.
# Key '4942546628751045490' not in persistent cache.
# Key '4096813786382043006' not in persistent cache.
# Key '-7140569516825854515' not in persistent cache.
# Key '-1924376647666637481' not in persistent cache.
# Key '5284984122835016614' not in persistent cache.
# Key '-4808846927993071179' not in persistent cache.
# Key '-9188861721845378394' not in persistent cache.
# Key '642666460743005711' not in persistent cache.
# Key '1259826657091075320' not in persistent cache.
# Key '-2241803819583427987' not in persistent cache.
# Key '4778896171638959589' not in persistent cache.
# Key '6200452844193025128' not in persistent cache.
# Key '2698822367518521821' not in persistent cache.
# Key '-4290096024602951866' not in persistent cache.
# Key '-828137406568450735' not in persistent cache.
# Key '1851140902031662413' not in persistent cache.
# Key '9060501672533316508' not in persistent cache.
# Key '5279304485897017989' not in persistent cache.
# Key '1720644943318058265' not in persistent cache.
# Key '874912100949055781' not in persistent cache.
# Key '8084272871450709876' not in persistent cache.
# Key '1899750955535232119' not in persistent cache.
# Key '2063082437402029389' not in persistent cache.
# Key '-984719324791201579' not in persistent cache.
# Key '6035980666431185997' not in persistent cache.
# Key '-2579235224689981514' not in persistent cache.
# Key '5083954260292944920' not in persistent cache.
# Key '-5463705505016415212' not in persistent cache.
# Key '1556994486205972364' not in persistent cache.
# Key '-8422163626314656888' not in persistent cache.
# Key '-523079317914465404' not in persistent cache.
# Key '-7511997710035939091' not in persistent cache.
# Key '2995990196633418865' not in persistent cache.
# Key '-1370760783401324812' not in persistent cache.
# Key '5838599987100329283' not in persistent cache.
# Key '9103432089098887589' not in persistent cache.
# Key '-316860285501712281' not in persistent cache.
# Key '-1162593127870714765' not in persistent cache.
# Key '6046767642630939330' not in persistent cache.
# Key '-137754273284538427' not in persistent cache.
# Key '-4372780174402109285' not in persistent cache.
# Key '-7420581936595340253' not in persistent cache.
# Key '-399881945372952677' not in persistent cache.
# Key '-4616740453509752060' not in persistent cache.
# Key '-1351908351511193754' not in persistent cache.
# Key '6547175956888997730' not in persistent cache.
# Key '-4878868125598166310' not in persistent cache.
# Key '3588717835590756054' not in persistent cache.
# Key '-2560584546734235950' not in persistent cache.
# Key '4498883751869473851' not in persistent cache.
# Key '958484967813648319' not in persistent cache.
# Key '-3408266012221095358' not in persistent cache.
# Key '-597262624703809391' not in persistent cache.
# Key '19897571644260218' not in persistent cache.
# Key '722364391139784810' not in persistent cache.
# Key '4274988931755150454' not in persistent cache.
# Key '7085992319272436421' not in persistent cache.
# Key '-6144558885277898161' not in persistent cache.
# Key '1064801885223755934' not in persistent cache.
# Key '-9029029165604331859' not in persistent cache.
# Key '5037700114252912542' not in persistent cache.
# Key '-3577515776868254969' not in persistent cache.
# Key '-2960355580520185360' not in persistent cache.
# Key '-6461986057194688667' not in persistent cache.
# Key '558713934027698909' not in persistent cache.
# Key '1980270606581764448' not in persistent cache.
# Key '-1521359870092738859' not in persistent cache.
# Key '-8510278262214212546' not in persistent cache.
# Key '-5048319644179711415' not in persistent cache.
# Key '-2369041335579598267' not in persistent cache.
# Key '-2205709853712800997' not in persistent cache.
# Key '5457479631270125437' not in persistent cache.
# Key '-3345546523286714522' not in persistent cache.
# Key '2854749922979139819' not in persistent cache.
# Key '3018081404845937089' not in persistent cache.
# Key '-3166440511069540668' not in persistent cache.
# Key '4042920259432113427' not in persistent cache.
# Key '-6050910791395974366' not in persistent cache.
# Key '969789199826413210' not in persistent cache.
# Key '-7645426691294754301' not in persistent cache.
# Key '17762793688172133' not in persistent cache.
# Key '-3483867682986331174' not in persistent cache.
# Key '3536832308236056402' not in persistent cache.
# Key '4958388980790121941' not in persistent cache.
# Key '-5589270784519238191' not in persistent cache.
# Key '5868554897068839738' not in persistent cache.
# Key '-2070201269971353922' not in persistent cache.
# Key '609077038628759226' not in persistent cache.
# Key '772408520495556496' not in persistent cache.
# Key '4037240622494114802' not in persistent cache.
# Key '-4046614772906028083' not in persistent cache.
# Key '2467017037870647686' not in persistent cache.
# Key '-5784194232473003619' not in persistent cache.
# Key '-6500461291724581883' not in persistent cache.
# Key '4098192537525640586' not in persistent cache.
# Key '-136833363591930272' not in persistent cache.
# Key '-1922997896523039901' not in persistent cache.
# Key '888005490994246066' not in persistent cache.
# Key '-9205825559833841727' not in persistent cache.
# Key '-2185125568611454151' not in persistent cache.
# Key '7646402613976929954' not in persistent cache.
# Key '-3137151974749695228' not in persistent cache.
# Key '4761932333650496256' not in persistent cache.
# Key '381917539798189041' not in persistent cache.
# Key '1803474212352254580' not in persistent cache.
# Key '-8744185552957105552' not in persistent cache.
# Key '2713640128630972377' not in persistent cache.
# Key '-5225116038409221283' not in persistent cache.
# Key '8854877055265586656' not in persistent cache.
# Key '-2382506247942310865' not in persistent cache.
# Key '5280683237040615569' not in persistent cache.
# Key '-5609051635640890750' not in persistent cache.
# Key '-6454784478009893234' not in persistent cache.
# Key '754576292491760861' not in persistent cache.
# Key '-5429945623423716896' not in persistent cache.
# Key '-5266614141556919626' not in persistent cache.
# Key '-8314415903750150594' not in persistent cache.
# Key '-5692073295512131146' not in persistent cache.
# Key '8537812270060621087' not in persistent cache.
# Key '-6644099701650372223' not in persistent cache.
# Key '5653341989734187389' not in persistent cache.
# Key '8275684597972206837' not in persistent cache.
# Key '2694883868435945713' not in persistent cache.
# Key '-7852775896873414419' not in persistent cache.
# Key '-793307598269704618' not in persistent cache.
# Key '-4333706382325530150' not in persistent cache.
# Key '-8700457362360273827' not in persistent cache.
# Key '-5889453974842987860' not in persistent cache.
# Key '1773735510139938574' not in persistent cache.
# Key '2727464939283771080' not in persistent cache.
# Key '6280089479899136724' not in persistent cache.
# Key '9091092867416422691' not in persistent cache.
# Key '7304928334485313062' not in persistent cache.
# Key '3069902433367742204' not in persistent cache.
# Key '22100671174511236' not in persistent cache.
# Key '7042800662396898812' not in persistent cache.
# Key '-1572415228724268699' not in persistent cache.
# Key '6090774256258657735' not in persistent cache.
# Key '-4456885509050702397' not in persistent cache.
# Key '2563814482171685179' not in persistent cache.
# Key '-7415343630348944073' not in persistent cache.
# Key '483740678051247411' not in persistent cache.
# Key '-6505177714070226276' not in persistent cache.
# Key '4002810192599131680' not in persistent cache.
# Key '-363940787435611997' not in persistent cache.
# Key '6845419983066042098' not in persistent cache.
# Key '-3938134605660583084' not in persistent cache.
# Key '8945536672465216939' not in persistent cache.
# Key '8099803830096214455' not in persistent cache.
# Key '-3137579473111683066' not in persistent cache.
# Key '2078613396047533968' not in persistent cache.
# Key '-9158769907160363553' not in persistent cache.
# Key '-805856884278899730' not in persistent cache.
# Key '6214843106943487846' not in persistent cache.
# Key '4645656504457177160' not in persistent cache.
# Key '5262816700805246769' not in persistent cache.
# Key '1761186224130743462' not in persistent cache.
# Key '8781886215353131038' not in persistent cache.
# Key '-8243301185802355039' not in persistent cache.
# Key '-344216877402163555' not in persistent cache.
# Key '-4685463363873148545' not in persistent cache.
# Key '3174852637145720714' not in persistent cache.
# Key '5854130945745833862' not in persistent cache.
# Key '6017462427612631132' not in persistent cache.
# Key '-9164449544098362178' not in persistent cache.
# Key '2267888526581995048' not in persistent cache.
# Key '-1896939874276813172' not in persistent cache.
# Key '2479569392607331612' not in persistent cache.
# Key '-5368520851851997535' not in persistent cache.
# Key '7087640356181429488' not in persistent cache.
# Key '609675032490951802' not in persistent cache.
# Key '-3037616007648886405' not in persistent cache.

# %% [markdown]
# # 1. Population DataFrames [A]

# %%
def population_df(years, age_range, area) -> pd.DataFrame: 
    """
    years (tuple): (start_year, end_year), use (year, year) if just want singular year
    age_range (tuple): (low_age, high_age)
    area (str): e.g. "India"

    This function takes in year, age_range, and area [country/world] and outputs a DataFrame with relevant information
    """
    country_id = wbdata.get_countries(query=area)[0]["id"]

    low, high = age_range
    ages = range(low, high + 1)

    indicators = {}
    for age in ages:
        age2 = f"{age:02d}"
        indicators[f"SP.POP.AG{age2}.MA.IN"] = f"male_{age2}"
        indicators[f"SP.POP.AG{age2}.FE.IN"] = f"female_{age2}"

    df = wbdata.get_dataframe(indicators, country=country_id, parse_dates=True)

    start, end = years
    df = df[(df.index.year >= start) & (df.index.year <= end)]

    return df

# %% [markdown]
# ### Population Df of India from 2010, male and female age 1-3

# %%
india_df = population_df((2000, 2010), (1, 3), "India")
india_df
# Out:
# Key '-6141512498473269617' not in persistent cache.
#                male_01   female_01     male_02   female_02     male_03  \
# date
# 2010-01-01  13495545.0  12298938.0  13415841.5  12215921.0  13456025.5
# 2009-01-01  13472670.5  12282255.0  13484389.5  12278052.5  13601170.5
# 2008-01-01  13548239.5  12352226.5  13634321.0  12407041.5  13782866.0
# 2007-01-01  13705075.0  12488959.0  13820419.0  12567362.0  13918835.0
# 2006-01-01  13894405.5  12653374.0  13957326.5  12693488.0  14008123.0
# 2005-01-01  14036289.5  12785347.5  14049018.5  12791509.5  14090686.0
# 2004-01-01  14133068.5  12889388.5  14134137.5  12865285.5  14053390.5
# 2003-01-01  14222743.0  12968494.5  14098552.5  12807316.5  13882771.5
# 2002-01-01  14193578.5  12917390.5  13931333.0  12647920.0  13743147.5
# 2001-01-01  14029296.5  12761370.5  13792863.5  12526431.5  13663218.5
# 2000-01-01  13893766.0  12643394.0  13714110.0  12461060.5  13583483.0
#
#              female_03
# date
# 2010-01-01  12244401.0
# 2009-01-01  12368019.5
# 2008-01-01  12523308.0
# 2007-01-01  12647810.0
# 2006-01-01  12742689.0
# 2005-01-01  12813192.0
# 2004-01-01  12752942.5
# 2003-01-01  12589598.0
# 2002-01-01  12466298.5
# 2001-01-01  12399016.5
# 2000-01-01  12342092.0

# %% [markdown]
# # 2. Population Statistics [A]

# %%
def population(years, sex, age_range, area):
    """
    years (tuple): (start_year, end_year) ,use (year, year) if just want singular year
    sex (str): "Male", "Female", or "All"
    age_range (tuple): (low_age, high_age)
    area (str): e.g. "India", "World"

    This function answers the question: 
    In [year] how many [people/males/females] aged [low] to [high] were living in [the world/region/country]?
    The output is a Series
    """
    df = population_df(years, age_range, area)
    df['male_total'] = df.filter(like='male_').sum(axis=1)
    df['female_total'] = df.filter(like='female_').sum(axis=1)
    df['population_total'] = df['female_total']+ df['male_total']
    
    #only the aggregated df
    agg = df[['male_total', 'female_total', 'population_total']]
    agg = agg.copy()
    agg.index = agg.index.year
    agg.index.name = "year"
    
    if sex == 'Female':
        return agg['female_total']
    elif sex == 'Male':
        return agg['male_total']
    elif sex == 'All':
        return agg['population_total']
    else:
        print("Invalid Input. Please input 'Female', 'Male', or 'All'.")

# %%
india_pop = population((1960, 1980), 'All', (0, 25), 'India')
india_pop
# Out:
# year
# 1980    623571902.5
# 1979    610692752.5
# 1978    598246339.0
# 1977    585930022.5
# 1976    573288815.0
# 1975    560623017.5
# 1974    547295452.0
# 1973    533674459.5
# 1972    520519766.5
# 1971    507794370.5
# 1970    495227950.0
# 1969    482914247.5
# 1968    471181696.0
# 1967    459718811.5
# 1966    448700331.0
# 1965    438052951.5
# 1964    427344124.5
# 1963    416661302.5
# 1962    406303217.5
# 1961    396137155.0
# 1960    386189746.0
# Name: population_total, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
india_pop.plot(ax=ax)

ax.set_xlabel("year")
ax.set_ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
india_pop.plot()
# Out:
# <Axes: xlabel='year'>

# %%
pakistan_pop = population((1960, 1980), 'All', (0, 3), '^Pakistan')
pakistan_pop
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-8465269564368692315' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3985283274301873254' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4818194257086983966' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3545039672589618006' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6462187382695132431' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3558496606663116836' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8189803749398628620' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4031354998732640943' not in persistent cache.
# year
# 1980    17240020.5
# 1979    16576323.5
# 1978    16014521.5
# 1977    15511875.5
# 1976    15046734.5
# 1975    14603069.5
# 1974    14176738.0
# 1973    13771771.5
# 1972    13394357.0
# 1971    13075763.0
# 1970    12780429.0
# 1969    12473397.0
# 1968    12170393.0
# 1967    11863796.5
# 1966    11555786.5
# 1965    11249729.0
# 1964    10940447.0
# 1963    10623704.0
# 1962    10300824.0
# 1961     9971769.0
# 1960     9639482.5
# Name: population_total, dtype: float64

# %%
pakistan_pop.plot()
# Out:
# <Axes: xlabel='year'>

# %%
bangladesh_pop = population((1960, 1980), 'All', (0, 25), 'Bangladesh')
bangladesh_pop

#age range [0, 25]
# Out:
# WARNING:shelved_cache.persistent_cache:Key '1187907353719198179' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2203609872792481488' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2773805508827113856' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-40768339787356006' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4163637022338913514' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2926172713578265499' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '832868640080241674' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5963849926146391247' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-40698534080837591' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1636525482694559229' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8876503614400966977' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5010166693491023134' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '71755259001494055' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5411907903366918649' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2710323695168680807' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1034588610073074097' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8967520904001679302' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-945203976239634658' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1091441949555465835' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '808449850252339316' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7185086596193910875' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1876306141158879530' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '16855812600053131' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3060066544109914114' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3517599779474378196' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4918795225562012625' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1748192929038501687' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6149440206508305671' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7037943032931565579' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6719417891444976542' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6762270942095319102' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1632442833722087213' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1562079748449291564' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8239453760115697078' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2410806620461073293' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7181084872495367536' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4011663578915609504' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '580392638725748451' not in persistent cache.
# year
# 1980    85161179.5
# 1979    83146561.5
# 1978    81132438.0
# 1977    79104452.5
# 1976    77044403.5
# 1975    74928072.5
# 1974    72718485.5
# 1973    70450245.5
# 1972    68277180.0
# 1971    66656747.0
# 1970    65246951.5
# 1969    63474230.5
# 1968    61573511.0
# 1967    59682290.0
# 1966    57847654.5
# 1965    56094691.5
# 1964    54389124.0
# 1963    52727489.5
# 1962    51110881.5
# 1961    49541864.0
# 1960    48065507.0
# Name: population_total, dtype: float64

# %%
bangladesh_pop.plot()
# Out:
# <Axes: xlabel='year'>

# %%
population_df().with_columns('Fertility Rate', wbdata['SP.DYN.TFRT.IN'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 population_df().with_columns('Fertility Rate', wbdata['SP.DYN.TFRT.IN'])
#
# TypeError: population_df() missing 3 required positional arguments: 'years', 'age_range', and 'area'

# %%
variable_labels = {"SP.POP.TOTL":"World Population"}
pakistan = wbdata.get_dataframe(variable_labels, country="PAK",parse_dates=True)
pakistan

# %%
country_id = wbdata.get_countries(query='Bangladesh')
country_id
# Out:
# id    name
# ----  ----------
# BGD   Bangladesh

# %%
infant_deaths_f = wbdata.get_indicators(source=40, query="Death")
infant_deaths_f
# Out:
# id              name
# --------------  ------------------------------------
# SH.DTH.0509     Number of deaths ages 5-9 years
# SH.DTH.0514     Number of deaths ages 5-14 years
# SH.DTH.1014     Number of deaths ages 10-14 years
# SH.DTH.1019     Number of deaths ages 10-19 years
# SH.DTH.1519     Number of deaths ages 15-19 years
# SH.DTH.2024     Number of deaths ages 20-24 years
# SH.DTH.IMRT     Number of infant deaths
# SH.DTH.IMRT.FE  Number of infant deaths, female
# SH.DTH.IMRT.MA  Number of infant deaths, male
# SH.DTH.MORT     Number of under-five deaths
# SH.DTH.MORT.FE  Number of under-five deaths, female
# SH.DTH.MORT.MA  Number of under-five deaths, male
# SH.DTH.NMRT     Number of neonatal deaths
# SP.DYN.CDRT.IN  Death rate, crude (per 1,000 people)

# %%
variable_labels = {"SH.DTH.IMRT.FE":"Number of infant deaths, female"}

INDIA_infant_deaths_female = wbdata.get_dataframe(variable_labels, country="IND",parse_dates=True)

# Print a few years' data
INDIA_infant_deaths_female.head()
# Out:
#             Number of infant deaths, female
# date
# 2024-01-01                              NaN
# 2023-01-01                         270562.0
# 2022-01-01                         283627.0
# 2021-01-01                         298537.0
# 2020-01-01                         319624.0

# %%
INDIA_infant_deaths_female.plot()
# Out:
# <Axes: xlabel='date'>

# %%
variable_labels = {"SH.DTH.IMRT.FE":"Number of infant deaths, female"}

BGD_infant_deaths_female = wbdata.get_dataframe(variable_labels, country="BGD",parse_dates=True)

# Print a few years' data
BGD_infant_deaths_female
# Out:
#             Number of infant deaths, female
# date
# 2024-01-01                              NaN
# 2023-01-01                          38399.0
# 2022-01-01                          38080.0
# 2021-01-01                          37698.0
# 2020-01-01                          37718.0
# ...                                     ...
# 1964-01-01                         194566.0
# 1963-01-01                         195414.0
# 1962-01-01                         195945.0
# 1961-01-01                         195652.0
# 1960-01-01                         194801.0
#
# [65 rows x 1 columns]
