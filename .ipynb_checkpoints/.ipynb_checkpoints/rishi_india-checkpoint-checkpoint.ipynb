# %% [markdown]
# <h1> Final Project 1 Jupyter Notebook: India, Pakistan, and Bangladesh </h1>
# <h2> Group 1: Dorothy Thomas </h2>
# <br/>
# <p>Authors: Rishi Boddu, Kita Hu, Sage Tulabing, Leanna Baltonado</p>
# <br/>
# <p>In this Jupyter Notebook, we'll be introducing population functions, population pyramid functions and more in order to quantify the 1994 Rwandan Genocide using data analysis. We primarily utilize the WBData Population dataset in order to compile data containing population for each age, gender, year, and country. We cite the information from WB Data. https://wbdata.readthedocs.io. We primarily aim to analyze the 1994 Rwandan Genocide using graphs and visualizations.</p>

# %%
# installations and importing data

# %pip install plotly
# %pip install wbdata
# %pip install eep153_tools
# %pip install python_gnupg
# %pip install -U gspread_pandas

from __future__ import annotations
import time
from functools import lru_cache
from typing import Literal
import wbdata
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: plotly in /srv/conda/lib/python3.11/site-packages (6.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly) (2.10.0)
# Requirement already satisfied: packaging in /srv/conda/lib/python3.11/site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting eep153_tools
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl.metadata (363 bytes)
# Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# Installing collected packages: eep153_tools
# Successfully installed eep153_tools-0.12.4
# Note: you may need to restart the kernel to use updated packages.
# Collecting python_gnupg
#   Using cached python_gnupg-0.5.6-py2.py3-none-any.whl.metadata (2.1 kB)
# Using cached python_gnupg-0.5.6-py2.py3-none-any.whl (22 kB)
# Installing collected packages: python_gnupg
# Successfully installed python_gnupg-0.5.6
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gspread_pandas in /srv/conda/lib/python3.11/site-packages (2.2.3)
# Collecting gspread_pandas
#   Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gspread<6,>=5.0.0 in /srv/conda/lib/python3.11/site-packages (from gspread_pandas) (5.12.4)
# Requirement already satisfied: pandas>=0.20.0 in /srv/conda/lib/python3.11/site-packages (from gspread_pandas) (2.2.3)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas) (5.1.1)
# Requirement already satisfied: google-auth in /srv/conda/lib/python3.11/site-packages (from gspread_pandas) (2.42.0)
# Requirement already satisfied: google-auth-oauthlib in /srv/conda/lib/python3.11/site-packages (from gspread_pandas) (1.2.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /srv/conda/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth->gspread_pandas) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib->gspread_pandas) (2.0.0)
# Requirement already satisfied: numpy>=1.23.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.20.0->gspread_pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.20.0->gspread_pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.20.0->gspread_pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.20.0->gspread_pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->gspread_pandas) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas) (2025.10.5)
# Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Installing collected packages: gspread_pandas
#   Attempting uninstall: gspread_pandas
#     Found existing installation: gspread-pandas 2.2.3
#     Uninstalling gspread-pandas-2.2.3:
#       Successfully uninstalled gspread-pandas-2.2.3
# Successfully installed gspread_pandas-3.3.0
# Note: you may need to restart the kernel to use updated packages.
# Key '76602575664523414' not in persistent cache.
# Key '-3286979994465856461' not in persistent cache.
# Key '-2642301090694614874' not in persistent cache.
# Key '5246786357559087773' not in persistent cache.
# Key '5403186149914994282' not in persistent cache.
# Key '1712894893961224456' not in persistent cache.
# Key '8922255664462878551' not in persistent cache.
# Key '-8102931736692607526' not in persistent cache.
# Key '-7206204830382742705' not in persistent cache.
# Key '-4583862222144723257' not in persistent cache.
# Key '-8950613202179466934' not in persistent cache.
# Key '-8053886295869602113' not in persistent cache.
# Key '6611660591203650984' not in persistent cache.
# Key '6865898003752976947' not in persistent cache.
# Key '-6383570093769823742' not in persistent cache.
# Key '-2949928626900855035' not in persistent cache.
# Key '314903475097703271' not in persistent cache.
# Key '3645137014215031583' not in persistent cache.
# Key '-7592246288992865938' not in persistent cache.
# Key '-532777990389156137' not in persistent cache.
# Key '6676582780112497958' not in persistent cache.
# Key '4740282391762673793' not in persistent cache.
# Key '498324801134212174' not in persistent cache.
# Key '1206390928164810476' not in persistent cache.
# Key '4017394315682096443' not in persistent cache.
# Key '-8609435702489021506' not in persistent cache.
# Key '-710351394088830022' not in persistent cache.
# Key '6310348597133557554' not in persistent cache.
# Key '8989626905733670702' not in persistent cache.
# Key '-1558032859575689430' not in persistent cache.
# Key '1706799242422868876' not in persistent cache.
# Key '1961036654972194839' not in persistent cache.
# Key '112283342524088941' not in persistent cache.
# Key '-7854789975681637143' not in persistent cache.
# Key '-4589957873683078837' not in persistent cache.
# Key '-1259724334565750525' not in persistent cache.
# Key '5949636435935903570' not in persistent cache.
# Key '-5437639339169938245' not in persistent cache.
# Key '-5274307857303140975' not in persistent cache.
# Key '-9026163519693268835' not in persistent cache.
# Key '5178622963387821162' not in persistent cache.
# Key '5886689090418419464' not in persistent cache.
# Key '8697692477935705431' not in persistent cache.
# Key '-3929137540235412518' not in persistent cache.
# Key '3969946768164778966' not in persistent cache.
# Key '-410068025687528249' not in persistent cache.
# Key '-4776819005722271926' not in persistent cache.
# Key '-8278449482396775233' not in persistent cache.
# Key '6387097404676477864' not in persistent cache.
# Key '6641334817225803827' not in persistent cache.
# Key '-6608133280296996862' not in persistent cache.
# Key '-3174491813428028155' not in persistent cache.
# Key '90340288570530151' not in persistent cache.
# Key '3420573827687858463' not in persistent cache.
# Key '-7816809475520039058' not in persistent cache.
# Key '-757341176916329257' not in persistent cache.
# Key '6452019593585324838' not in persistent cache.
# Key '6056410034280141189' not in persistent cache.
# Key '6212809826636047698' not in persistent cache.
# Key '2522518570682277872' not in persistent cache.
# Key '-8714864732525619649' not in persistent cache.
# Key '-7293308059971554110' not in persistent cache.
# Key '5004133631413005502' not in persistent cache.
# Key '-3774238545423669841' not in persistent cache.
# Key '-8140989525458413518' not in persistent cache.
# Key '-7244262619148548697' not in persistent cache.
# Key '7421284267924704400' not in persistent cache.
# Key '7675521680474030363' not in persistent cache.
# Key '-5573946417048770326' not in persistent cache.
# Key '-2140304950179801619' not in persistent cache.
# Key '1124527151818756687' not in persistent cache.
# Key '4454760690936084999' not in persistent cache.
# Key '-6782622612271812522' not in persistent cache.
# Key '276845686331897279' not in persistent cache.
# Key '7486206456833551374' not in persistent cache.
# Key '2915078232622085876' not in persistent cache.
# Key '-866118954014212643' not in persistent cache.
# Key '-611881541464886680' not in persistent cache.
# Key '4585394434721864247' not in persistent cache.
# Key '8019035901590832954' not in persistent cache.
# Key '-7162876070120160356' not in persistent cache.
# Key '-3832642531002832044' not in persistent cache.
# Key '3376718239498822051' not in persistent cache.
# Key '-8010557535607019764' not in persistent cache.
# Key '-801196765105365669' not in persistent cache.
# Key '3805622284269000450' not in persistent cache.
# Key '3962022076624906959' not in persistent cache.
# Key '271730820671137133' not in persistent cache.
# Key '435062302537934403' not in persistent cache.
# Key '1856618975091999942' not in persistent cache.
# Key '-1645011501582503365' not in persistent cache.
# Key '5375688489639884211' not in persistent cache.
# Key '8054966798239997359' not in persistent cache.
# Key '-2492692967069362773' not in persistent cache.
# Key '5170496517913563661' not in persistent cache.
# Key '1026376547478521496' not in persistent cache.
# Key '3575980618014783726' not in persistent cache.
# Key '2611264701899384305' not in persistent cache.
# Key '-8172289886827240877' not in persistent cache.
# Key '-4842056347709912565' not in persistent cache.
# Key '-2031052960192626598' not in persistent cache.
# Key '-9019971352314100285' not in persistent cache.
# Key '-1810610581812446190' not in persistent cache.
# Key '1928302987122344717' not in persistent cache.
# Key '2084702779478251226' not in persistent cache.
# Key '-1605588476475518600' not in persistent cache.
# Key '5603772294026135495' not in persistent cache.
# Key '7025328966580201034' not in persistent cache.
# Key '3523698489905697727' not in persistent cache.
# Key '-7902345592581466313' not in persistent cache.
# Key '6177647501093341626' not in persistent cache.
# Key '2676017024418838319' not in persistent cache.
# Key '3293177220766907928' not in persistent cache.
# Key '-850942749668134237' not in persistent cache.
# Key '8744690609502984818' not in persistent cache.
# Key '7779974693387585397' not in persistent cache.
# Key '-3003579895339039785' not in persistent cache.
# Key '326653643778288527' not in persistent cache.
# Key '3137657031295574494' not in persistent cache.
# Key '-3851261360825899193' not in persistent cache.
# Key '-1040257973308613226' not in persistent cache.
# Key '6704137606621767539' not in persistent cache.
# Key '6860537398977674048' not in persistent cache.
# Key '3170246143023904222' not in persistent cache.
# Key '3333577624890701492' not in persistent cache.
# Key '-6645580487629927760' not in persistent cache.
# Key '1253503820770263724' not in persistent cache.
# Key '8274203811992651300' not in persistent cache.
# Key '-7493261953116787168' not in persistent cache.
# Key '405822355283404316' not in persistent cache.
# Key '8069011840266330750' not in persistent cache.
# Key '3924891869831288585' not in persistent cache.
# Key '6474495940367550815' not in persistent cache.
# Key '-5890934760822543397' not in persistent cache.
# Key '-5273774564474473788' not in persistent cache.
# Key '5102488263277711349' not in persistent cache.
# Key '5265819745144508619' not in persistent cache.
# Key '924573258673523629' not in persistent cache.
# Key '1087904740540320899' not in persistent cache.
# Key '-8337509476388334418' not in persistent cache.
# Key '-8181109684032427909' not in persistent cache.
# Key '6575343133723353881' not in persistent cache.
# Key '-4662040169484543640' not in persistent cache.
# Key '-3240483496930478101' not in persistent cache.
# Key '-6742113973604981408' not in persistent cache.
# Key '278586017617406168' not in persistent cache.
# Key '-4088164962417337509' not in persistent cache.
# Key '-7589795439091840816' not in persistent cache.
# Key '-6972635242743771207' not in persistent cache.
# Key '7329988860530738244' not in persistent cache.
# Key '-1521121854007694317' not in persistent cache.
# Key '-2485837770123093738' not in persistent cache.
# Key '5177351714859832696' not in persistent cache.
# Key '8507585253977161008' not in persistent cache.
# Key '-7128155432215104641' not in persistent cache.
# Key '4329670249372973288' not in persistent cache.
# Key '-6907713053834924233' not in persistent cache.
# Key '-4245676896936724279' not in persistent cache.
# Key '-4089277104580817770' not in persistent cache.
# Key '-3381210977550219468' not in persistent cache.
# Key '-7616236878667790326' not in persistent cache.
# Key '-1796322823129356659' not in persistent cache.
# Key '-5297953299803859966' not in persistent cache.
# Key '-2675610691565840518' not in persistent cache.
# Key '4402025000018640758' not in persistent cache.
# Key '-6145634765290719374' not in persistent cache.
# Key '-2880802663292161068' not in persistent cache.
# Key '-2626565250742835105' not in persistent cache.
# Key '-4475318563190941003' not in persistent cache.
# Key '-1041677096321972296' not in persistent cache.
# Key '2223155005676586010' not in persistent cache.

# %%
wbdata.get_countries(query="India")[0]['id']
# Out:
# 'IND'

# %%
wbdata.get_countries(query="Pakistan")[0]['id']
# Out:
# 'BMN'

# %%
wbdata.get_countries(query="Bangladesh")[0]['id']
# Out:
# 'BGD'

# %%
#wbdata.get_indicators()
SOURCE = 40 # "Population estimates and projections

indicators = wbdata.get_indicators(source=SOURCE)
indicators
# Out:
# id                 name
# -----------------  -------------------------------------------------------------------
# SH.DTH.0509        Number of deaths ages 5-9 years
# SH.DTH.0514        Number of deaths ages 5-14 years
# SH.DTH.1014        Number of deaths ages 10-14 years
# SH.DTH.1019        Number of deaths ages 10-19 years
# SH.DTH.1519        Number of deaths ages 15-19 years
# SH.DTH.2024        Number of deaths ages 20-24 years
# SH.DTH.IMRT        Number of infant deaths
# SH.DTH.IMRT.FE     Number of infant deaths, female
# SH.DTH.IMRT.MA     Number of infant deaths, male
# SH.DTH.MORT        Number of under-five deaths
# SH.DTH.MORT.FE     Number of under-five deaths, female
# SH.DTH.MORT.MA     Number of under-five deaths, male
# SH.DTH.NMRT        Number of neonatal deaths
# SH.DYN.0509        Probability of dying among children ages 5-9 years (per 1,000)
# SH.DYN.0514        Probability of dying at age 5-14 years (per 1,000 children age 5)
# SH.DYN.1014        Probability of dying among adolescents ages 10-14 years (per 1,000)
# SH.DYN.1019        Probability of dying among adolescents ages 10-19 years (per 1,000)
# SH.DYN.1519        Probability of dying among adolescents ages 15-19 years (per 1,000)
# SH.DYN.2024        Probability of dying among youth ages 20-24 years (per 1,000)
# SH.DYN.MORT        Mortality rate, under-5 (per 1,000 live births)
# SH.DYN.MORT.FE     Mortality rate, under-5, female (per 1,000 live births)
# SH.DYN.MORT.MA     Mortality rate, under-5, male (per 1,000 live births)
# SH.DYN.NMRT        Mortality rate, neonatal (per 1,000 live births)
# SM.POP.NETM        Net migration
# SP.DYN.AMRT.FE     Mortality rate, adult, female (per 1,000 female adults)
# SP.DYN.AMRT.MA     Mortality rate, adult, male (per 1,000 male adults)
# SP.DYN.CBRT.IN     Birth rate, crude (per 1,000 people)
# SP.DYN.CDRT.IN     Death rate, crude (per 1,000 people)
# SP.DYN.IMRT.FE.IN  Mortality rate, infant, female (per 1,000 live births)
# SP.DYN.IMRT.IN     Mortality rate, infant (per 1,000 live births)
# SP.DYN.IMRT.MA.IN  Mortality rate, infant, male (per 1,000 live births)
# SP.DYN.LE00.FE.IN  Life expectancy at birth, female (years)
# SP.DYN.LE00.IN     Life expectancy at birth, total (years)
# SP.DYN.LE00.MA.IN  Life expectancy at birth, male (years)
# SP.DYN.TFRT.IN     Fertility rate, total (births per woman)
# SP.POP.0004.FE     Population ages 00-04, female
# SP.POP.0004.FE.5Y  Population ages 00-04, female (% of female population)
# SP.POP.0004.MA     Population ages 00-04, male
# SP.POP.0004.MA.5Y  Population ages 00-04, male (% of male population)
# SP.POP.0014.FE.IN  Population ages 0-14, female
# SP.POP.0014.FE.ZS  Population ages 0-14, female (% of female population)
# SP.POP.0014.MA.IN  Population ages 0-14, male
# SP.POP.0014.MA.ZS  Population ages 0-14, male (% of male population)
# SP.POP.0014.TO     Population ages 0-14, total
# SP.POP.0014.TO.ZS  Population ages 0-14 (% of total population)
# SP.POP.0509.FE     Population ages 05-09, female
# SP.POP.0509.FE.5Y  Population ages 05-09, female (% of female population)
# SP.POP.0509.MA     Population ages 05-09, male
# SP.POP.0509.MA.5Y  Population ages 05-09, male (% of male population)
# SP.POP.1014.FE     Population ages 10-14, female
# SP.POP.1014.FE.5Y  Population ages 10-14, female (% of female population)
# SP.POP.1014.MA     Population ages 10-14, male
# SP.POP.1014.MA.5Y  Population ages 10-14, male (% of male population)
# SP.POP.1519.FE     Population ages 15-19, female
# SP.POP.1519.FE.5Y  Population ages 15-19, female (% of female population)
# SP.POP.1519.MA     Population ages 15-19, male
# SP.POP.1519.MA.5Y  Population ages 15-19, male (% of male population)
# SP.POP.1564.FE.IN  Population ages 15-64, female
# SP.POP.1564.FE.ZS  Population ages 15-64, female (% of female population)
# SP.POP.1564.MA.IN  Population ages 15-64, male
# SP.POP.1564.MA.ZS  Population ages 15-64, male (% of male population)
# SP.POP.1564.TO     Population ages 15-64, total
# SP.POP.1564.TO.ZS  Population ages 15-64 (% of total population)
# SP.POP.2024.FE     Population ages 20-24, female
# SP.POP.2024.FE.5Y  Population ages 20-24, female (% of female population)
# SP.POP.2024.MA     Population ages 20-24, male
# SP.POP.2024.MA.5Y  Population ages 20-24, male (% of male population)
# SP.POP.2529.FE     Population ages 25-29, female
# SP.POP.2529.FE.5Y  Population ages 25-29, female (% of female population)
# SP.POP.2529.MA     Population ages 25-29, male
# SP.POP.2529.MA.5Y  Population ages 25-29, male (% of male population)
# SP.POP.3034.FE     Population ages 30-34, female
# SP.POP.3034.FE.5Y  Population ages 30-34, female (% of female population)
# SP.POP.3034.MA     Population ages 30-34, male
# SP.POP.3034.MA.5Y  Population ages 30-34, male (% of male population)
# SP.POP.3539.FE     Population ages 35-39, female
# SP.POP.3539.FE.5Y  Population ages 35-39, female (% of female population)
# SP.POP.3539.MA     Population ages 35-39, male
# SP.POP.3539.MA.5Y  Population ages 35-39, male (% of male population)
# SP.POP.4044.FE     Population ages 40-44, female
# SP.POP.4044.FE.5Y  Population ages 40-44, female (% of female population)
# SP.POP.4044.MA     Population ages 40-44, male
# SP.POP.4044.MA.5Y  Population ages 40-44, male (% of male population)
# SP.POP.4549.FE     Population ages 45-49, female
# SP.POP.4549.FE.5Y  Population ages 45-49, female (% of female population)
# SP.POP.4549.MA     Population ages 45-49, male
# SP.POP.4549.MA.5Y  Population ages 45-49, male (% of male population)
# SP.POP.5054.FE     Population ages 50-54, female
# SP.POP.5054.FE.5Y  Population ages 50-54, female (% of female population)
# SP.POP.5054.MA     Population ages 50-54, male
# SP.POP.5054.MA.5Y  Population ages 50-54, male (% of male population)
# SP.POP.5559.FE     Population ages 55-59, female
# SP.POP.5559.FE.5Y  Population ages 55-59, female (% of female population)
# SP.POP.5559.MA     Population ages 55-59, male
# SP.POP.5559.MA.5Y  Population ages 55-59, male (% of male population)
# SP.POP.6064.FE     Population ages 60-64, female
# SP.POP.6064.FE.5Y  Population ages 60-64, female (% of female population)
# SP.POP.6064.MA     Population ages 60-64, male
# SP.POP.6064.MA.5Y  Population ages 60-64, male (% of male population)
# SP.POP.6569.FE     Population ages 65-69, female
# SP.POP.6569.FE.5Y  Population ages 65-69, female (% of female population)
# SP.POP.6569.MA     Population ages 65-69, male
# SP.POP.6569.MA.5Y  Population ages 65-69, male (% of male population)
# SP.POP.65UP.FE.IN  Population ages 65 and above, female
# SP.POP.65UP.FE.ZS  Population ages 65 and above, female (% of female population)
# SP.POP.65UP.MA.IN  Population ages 65 and above, male
# SP.POP.65UP.MA.ZS  Population ages 65 and above, male (% of male population)
# SP.POP.65UP.TO     Population ages 65 and above, total
# SP.POP.65UP.TO.ZS  Population ages 65 and above (% of total population)
# SP.POP.7074.FE     Population ages 70-74, female
# SP.POP.7074.FE.5Y  Population ages 70-74, female (% of female population)
# SP.POP.7074.MA     Population ages 70-74, male
# SP.POP.7074.MA.5Y  Population ages 70-74, male (% of male population)
# SP.POP.7579.FE     Population ages 75-79, female
# SP.POP.7579.FE.5Y  Population ages 75-79, female (% of female population)
# SP.POP.7579.MA     Population ages 75-79, male
# SP.POP.7579.MA.5Y  Population ages 75-79, male (% of male population)
# SP.POP.80UP.FE     Population ages 80 and above, female
# SP.POP.80UP.FE.5Y  Population ages 80 and above, female (% of female population)
# SP.POP.80UP.MA     Population ages 80 and above, male
# SP.POP.80UP.MA.5Y  Population ages 80 and above, male (% of male population)
# SP.POP.AG00.FE.IN  Age population, age 00, female, interpolated
# SP.POP.AG00.MA.IN  Age population, age 00, male, interpolated
# SP.POP.AG01.FE.IN  Age population, age 01, female, interpolated
# SP.POP.AG01.MA.IN  Age population, age 01, male, interpolated
# SP.POP.AG02.FE.IN  Age population, age 02, female, interpolated
# SP.POP.AG02.MA.IN  Age population, age 02, male, interpolated
# SP.POP.AG03.FE.IN  Age population, age 03, female, interpolated
# SP.POP.AG03.MA.IN  Age population, age 03, male, interpolated
# SP.POP.AG04.FE.IN  Age population, age 04, female, interpolated
# SP.POP.AG04.MA.IN  Age population, age 04, male, interpolated
# SP.POP.AG05.FE.IN  Age population, age 05, female, interpolated
# SP.POP.AG05.MA.IN  Age population, age 05, male, interpolated
# SP.POP.AG06.FE.IN  Age population, age 06, female, interpolated
# SP.POP.AG06.MA.IN  Age population, age 06, male, interpolated
# SP.POP.AG07.FE.IN  Age population, age 07, female, interpolated
# SP.POP.AG07.MA.IN  Age population, age 07, male, interpolated
# SP.POP.AG08.FE.IN  Age population, age 08, female, interpolated
# SP.POP.AG08.MA.IN  Age population, age 08, male, interpolated
# SP.POP.AG09.FE.IN  Age population, age 09, female, interpolated
# SP.POP.AG09.MA.IN  Age population, age 09, male, interpolated
# SP.POP.AG10.FE.IN  Age population, age 10, female, interpolated
# SP.POP.AG10.MA.IN  Age population, age 10, male, interpolated
# SP.POP.AG11.FE.IN  Age population, age 11, female, interpolated
# SP.POP.AG11.MA.IN  Age population, age 11, male, interpolated
# SP.POP.AG12.FE.IN  Age population, age 12, female, interpolated
# SP.POP.AG12.MA.IN  Age population, age 12, male, interpolated
# SP.POP.AG13.FE.IN  Age population, age 13, female, interpolated
# SP.POP.AG13.MA.IN  Age population, age 13, male, interpolated
# SP.POP.AG14.FE.IN  Age population, age 14, female, interpolated
# SP.POP.AG14.MA.IN  Age population, age 14, male, interpolated
# SP.POP.AG15.FE.IN  Age population, age 15, female, interpolated
# SP.POP.AG15.MA.IN  Age population, age 15, male, interpolated
# SP.POP.AG16.FE.IN  Age population, age 16, female, interpolated
# SP.POP.AG16.MA.IN  Age population, age 16, male, interpolated
# SP.POP.AG17.FE.IN  Age population, age 17, female, interpolated
# SP.POP.AG17.MA.IN  Age population, age 17, male, interpolated
# SP.POP.AG18.FE.IN  Age population, age 18, female, interpolated
# SP.POP.AG18.MA.IN  Age population, age 18, male, interpolated
# SP.POP.AG19.FE.IN  Age population, age 19, female, interpolated
# SP.POP.AG19.MA.IN  Age population, age 19, male, interpolated
# SP.POP.AG20.FE.IN  Age population, age 20, female, interpolated
# SP.POP.AG20.MA.IN  Age population, age 20, male, interpolated
# SP.POP.AG21.FE.IN  Age population, age 21, female, interpolated
# SP.POP.AG21.MA.IN  Age population, age 21, male, interpolated
# SP.POP.AG22.FE.IN  Age population, age 22, female, interpolated
# SP.POP.AG22.MA.IN  Age population, age 22, male, interpolated
# SP.POP.AG23.FE.IN  Age population, age 23, female, interpolated
# SP.POP.AG23.MA.IN  Age population, age 23, male, interpolated
# SP.POP.AG24.FE.IN  Age population, age 24, female, interpolated
# SP.POP.AG24.MA.IN  Age population, age 24, male, interpolated
# SP.POP.AG25.FE.IN  Age population, age 25, female, interpolated
# SP.POP.AG25.MA.IN  Age population, age 25, male, interpolated
# SP.POP.BRTH.MF     Sex ratio at birth (male births per female births)
# SP.POP.DPND        Age dependency ratio (% of working-age population)
# SP.POP.DPND.OL     Age dependency ratio, old (% of working-age population)
# SP.POP.DPND.YG     Age dependency ratio, young (% of working-age population)
# SP.POP.GROW        Population growth (annual %)
# SP.POP.TOTL        Population, total
# SP.POP.TOTL.FE.IN  Population, female
# SP.POP.TOTL.FE.ZS  Population, female (% of total population)
# SP.POP.TOTL.MA.IN  Population, male
# SP.POP.TOTL.MA.ZS  Population, male (% of total population)
# SP.RUR.TOTL        Rural population
# SP.RUR.TOTL.ZG     Rural population growth (annual %)
# SP.RUR.TOTL.ZS     Rural population (% of total population)
# SP.URB.GROW        Urban population growth (annual %)
# SP.URB.TOTL        Urban population
# SP.URB.TOTL.IN.ZS  Urban population (% of total population)

# %% [markdown]
# <h1> [A] Population Dataframe</h1>

# %% [markdown]
# <h4> Helper Functions </h4>

# %%
#Helper Functions

Sex = Literal["female", "male", "total"]

AGE_BINS_5Y = [
    "0004","0509","1014","1519","2024","2529","3034","3539",
    "4044","4549","5054","5559","6064","6569","7074","7579","80UP"
]

BIN_TO_RANGE = {
    "0004": (0,4),   "0509": (5,9),   "1014": (10,14), "1519": (15,19),
    "2024": (20,24), "2529": (25,29), "3034": (30,34), "3539": (35,39),
    "4044": (40,44), "4549": (45,49), "5054": (50,54), "5559": (55,59),
    "6064": (60,64), "6569": (65,69), "7074": (70,74), "7579": (75,79),
    "80UP": (80,200),
}

def bins_for_age_range(start_age: int, end_age: int) -> list[str]:
    ''' >>> bins_for_age_range(start_age = 0, end_age = 9)
        return: ['0004', '0509']
        '''
    return [b for b,(lo,hi) in BIN_TO_RANGE.items() if not (hi < start_age or lo > end_age)]

def wb_indicator_5y(age_code: str, sex: str) -> str:
    ''' This helper constructs variable indicator.
    >>> wb_indicator_5y(age_code = '0004', sex = 'female')
    output: "SP.POP.0004.FE"
    '''
    
    sex_code = "FE" if sex == "female" else "MA"
    return f"SP.POP.{age_code}.{sex_code}"

# %% [markdown]
# <h4> Validation Functions </h4>

# %%
#validation functions 
def _validate_years(years: tuple[int, int]) -> None:
    if (not isinstance(years, tuple)) or len(years) != 2:
        raise TypeError("years must be a tuple of (start_year, end_year)")
    y0, y1 = years
    if not (isinstance(y0, int) and isinstance(y1, int)):
        raise TypeError("years must contain integers")
    if y0 > y1:
        raise ValueError("years must satisfy start_year <= end_year")
    if y0 < 1960 or y1 > 2024:
        raise ValueError("years must be between 1960 and 2024, inclusive")


def _validate_area(area: str) -> str:
    if not isinstance(area, str):
        raise TypeError("area must be a string")
    area = area.strip()
    if not area:
        raise ValueError("area must be a non-empty string")
    return area


def _validate_sex(sex: str) -> Sex:
    if not isinstance(sex, str):
        raise TypeError("sex must be a string")
    sex = sex.strip().lower()
    if sex not in ("female", "male", "total"):
        raise ValueError("sex must be 'female', 'male', or 'total'")
    return sex  # type: ignore[return-value]


def _validate_age_range(age_range: tuple[int, int]) -> tuple[int, int]:
    if (not isinstance(age_range, tuple)) or len(age_range) != 2:
        raise TypeError("age_range must be a tuple (low, high)")
    low, high = age_range
    if not (isinstance(low, int) and isinstance(high, int)):
        raise TypeError("age_range bounds must be integers")
    if low < 0 or high < 0:
        raise ValueError("age_range bounds must be non-negative")
    if low > high:
        raise ValueError("age_range must satisfy low <= high")

    # Exact 5-year boundary validation:
    # valid ranges are unions of 5-year bins, so:
    #   low must be multiple of 5
    #   high must be 4 mod 5
    if (low % 5) != 0 or (high % 5) != 4:
        raise ValueError(
            "age_range must align to 5-year bins, e.g. (0,4), (0,9), (5,14), (15,19)"
        )

    # Optional: enforce max bound if your bins top out (e.g., 100+)
    # You can skip this if AGE_BINS_5Y already handles it robustly.
    return low, high

# %% [markdown]
# <h4> The Actual Population Dataframe Function </h4>

# %%
@lru_cache(maxsize=128)
def population_df(years: tuple[int, int], area: str, chunk: int = 4) -> pd.DataFrame:
    """
    Example: india_pop_df = population_df(years=(2018, 2020), area="India")
    Returns a DataFrame with male and female counts of each 5-year age range.
    Please enter a year between 1960 and 2024. 
    """
    _validate_years(years)
    area = _validate_area(area)
    if not isinstance(chunk, int) or chunk <= 0:
        raise ValueError("chunk must be a positive integer")

    # Resolve country id (kept inside cached function; caching avoids repeat lookups too)
    countries = wbdata.get_countries(query=f"^{re.escape(area)}$")
    if not countries:
        raise ValueError(f"No country matched area={area!r}")
    country_id = countries[0]["id"]

    def fetch(sub_bins: list[str]) -> pd.DataFrame:
        indicators: dict[str, str] = {}
        for b in sub_bins:
            indicators[wb_indicator_5y(b, "female")] = f"female_{b}"
            indicators[wb_indicator_5y(b, "male")] = f"male_{b}"

        last_err: Exception | None = None
        for k in range(5):
            try:
                # Note: skip_cache=True means "do not use wbdata's cache".
                # Our lru_cache handles caching at the function level.
                return wbdata.get_dataframe(
                    indicators,
                    country=country_id,
                    parse_dates=True,
                    skip_cache=True,
                )
            except Exception as e:
                last_err = e
                time.sleep(0.5 * (2 ** k))
        assert last_err is not None
        raise last_err

    parts: list[pd.DataFrame] = []
    for i in range(0, len(AGE_BINS_5Y), chunk):
        parts.append(fetch(AGE_BINS_5Y[i : i + chunk]))

    df = pd.concat(parts, axis=1)

    # Ensure datetime-like index
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index.astype(str), errors="coerce")

    y0, y1 = years
    df = df[(df.index.year >= y0) & (df.index.year <= y1)]

    # Consistent column order: female bins then male bins
    df = df[[f"female_{b}" for b in AGE_BINS_5Y] + [f"male_{b}" for b in AGE_BINS_5Y]]

    df.index = df.index.year
    return df

# %% [markdown]
# <h4> Example Usage </h4>

# %%
# india
india_pop_df = population_df(
    years=(2018, 2020),
    area="India"
)
india_pop_df
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-5847326240280780469' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5683994758413983199' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1375473540189726602' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8584834310691380697' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3997685447487018041' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3841285655131111532' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7531576911084881358' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6680141261507099400' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1099340531970838276' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8998424840371029760' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2427619242116134280' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '251659066483978868' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8150743374884170352' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2632811213842454830' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6776931184277496995' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4227327113741234765' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1853986258778222639' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1927210927858075880' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8449051899894109257' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8612383381760906527' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4271136895289921537' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4434468377156718807' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5856025049710784346' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3018852672452578063' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-9071649509450883001' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5612064770603141571' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2110434293928638264' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '9131134285151025840' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1416525480158334292' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1848306621840224014' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '62142088909114385' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7352287866528099217' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7863175068162226299' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-653814297660572204' not in persistent cache.
#       female_0004  female_0509  female_1014  female_1519  female_2024  \
# date
# 2020   56846872.0   58963120.0   60665244.0   62395896.0   60243689.0
# 2019   57282565.0   59639765.0   60964654.0   62398981.0   59826923.0
# 2018   57658903.0   60182984.0   61358955.0   62178615.0   59493195.0
#
#       female_2529  female_3034  female_3539  female_4044  female_4549  ...  \
# date                                                                   ...
# 2020   57840211.0   54935788.0   49741493.0   43638105.0   38698224.0  ...
# 2019   57450398.0   54201524.0   48603778.0   42701924.0   37828159.0  ...
# 2018   57071892.0   53371842.0   47428167.0   41890672.0   36968547.0  ...
#
#        male_3539   male_4044   male_4549   male_5054   male_5559   male_6064  \
# date
# 2020  53887018.0  46734880.0  40676622.0  34948447.0  29842077.0  24391302.0
# 2019  52655474.0  45655208.0  39720245.0  34265392.0  29253476.0  23856378.0
# 2018  51357720.0  44714951.0  38790269.0  33606373.0  28617405.0  23257654.0
#
#        male_6569   male_7074  male_7579  male_80UP
# date
# 2020  18414252.0  11412174.0  6763527.0  6022397.0
# 2019  17744267.0  10729139.0  6563601.0  5848977.0
# 2018  16881262.0  10184368.0  6369273.0  5610832.0
#
# [3 rows x 34 columns]

# %%
# pakistan
pakistan_pop_df = population_df(
    years=(2018, 2020),
    area="Pakistan"
)
pakistan_pop_df

# %%
# bangladesh
bangladesh_pop_df = population_df(
    years=(2018, 2020),
    area="Bangladesh"
)
bangladesh_pop_df
# Out:
# WARNING:shelved_cache.persistent_cache:Key '8950992105784881897' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2857485550957263780' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6256422170259636332' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6451445138934426042' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5696350317911985116' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6967110177540028731' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3219307339521382825' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7767373612482535752' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2599533608584420821' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1251767794729603250' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3928103677150585889' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6299504152123226502' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2963166564260227260' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5152042462260894165' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5552803775109335883' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1587269703374058074' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8413039336400777600' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3677845993494149944' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7031686151916889375' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3460562014756722385' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8227789332341794052' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8732485440052091581' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4010612558852442971' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8920885990117424703' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2039366471337461629' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '771676863434702250' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6307090287238101001' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-710896465299479288' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '85726285920077780' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '9084344481982897958' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7622729019345768282' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4441906013042275337' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5821246490410834809' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3110192607047442280' not in persistent cache.
#       female_0004  female_0509  female_1014  female_1519  female_2024  \
# date
# 2020    7746950.0    7613840.0    8284906.0    8748000.0    8402872.0
# 2019    7672802.0    7652839.0    8400369.0    8709213.0    8198837.0
# 2018    7614705.0    7722231.0    8490530.0    8649599.0    7930168.0
#
#       female_2529  female_3034  female_3539  female_4044  female_4549  ...  \
# date                                                                   ...
# 2020    7450277.0    6732030.0    6308133.0    4948399.0    4316810.0  ...
# 2019    7211497.0    6758736.0    6097405.0    5009833.0    4325774.0  ...
# 2018    7084157.0    6717282.0    5971400.0    5084278.0    4303487.0  ...
#
#       male_3539  male_4044  male_4549  male_5054  male_5559  male_6064  \
# date
# 2020  5835444.0  4805839.0  4052711.0  3501273.0  3030756.0  2523977.0
# 2019  5600201.0  4648536.0  3975248.0  3461014.0  3005075.0  2473877.0
# 2018  5369942.0  4533173.0  3898406.0  3427467.0  2974856.0  2406654.0
#
#       male_6569  male_7074  male_7579  male_80UP
# date
# 2020  1916516.0  1299119.0   844722.0   631202.0
# 2019  1824725.0  1279477.0   809215.0   593632.0
# 2018  1724425.0  1255624.0   768982.0   551648.0
#
# [3 rows x 34 columns]

# %% [markdown]
# <h1>[A] Population Statistics</h1>

# %% [markdown]
# <p> This function answers the question: In [year] how many [people/males/females] aged [low] to [high] were living in [the world/region/country]? </p>

# %%
def population_stats(
    year: int,
    sex: str,
    age_range: tuple[int, int],
    area: str,
) -> int:
    """
    Returns the population count as an integer.
    For variable sex, please enter 'female, 'male', or 'total'.
    Age range should also follow five the head and tail of 5-year range
    ex. 0-4, 5-9, 5-14, 15-29 

    Example:
    pakistan_pop_stats = population_stats(year= 2000, 
                     sex= 'total', 
                     age_range= (15, 29), 
                     area= 'Pakistan')
    output: 41045700
    """
    if not isinstance(year, int):
        raise TypeError("year must be an int")
    if year < 1960 or year > 2024:
        raise ValueError("year must be between 1960 and 2024")

    sex_v = _validate_sex(sex)
    low, high = _validate_age_range(age_range)
    area = _validate_area(area)

    df = population_df((year, year), area)
    if df.empty:
        raise ValueError(f"No data returned for {area!r} in {year}")

    row = df.iloc[0]
    bins = bins_for_age_range(low, high)

    if sex_v == "female":
        count = sum(row[f"female_{b}"] for b in bins)
    elif sex_v == "male":
        count = sum(row[f"male_{b}"] for b in bins)
    else:  # total
        count = sum(row[f"female_{b}"] + row[f"male_{b}"] for b in bins)

    # Be robust to floats/NaNs coming back from wbdata
    if pd.isna(count):
        raise ValueError("Population count is NaN (missing data for one or more bins)")
    return int(count)


def format_population_stats_sentence(
    year: int,
    sex: str,
    age_range: tuple[int, int],
    area: str,
) -> str:
    """
    This returns the wrapper that produces the sentence: 
    In [year] how many [people/males/females] aged [low] to [high] 
    were living in [the world/region/country]?

    """
    sex_v = _validate_sex(sex)
    low, high = _validate_age_range(age_range)
    area = _validate_area(area)

    count = population_stats(year, sex_v, (low, high), area)

    who = {"female": "females", "male": "males", "total": "people"}[sex_v]
    return f"In {year}, there were {count:,} {who} aged {low} to {high} living in {area}."

# %% [markdown]
# <h4> Example Usage of the Population Function </h4>

# %%
india_pop_stats = format_population_stats_sentence(year= 2000, 
                     sex= 'female', 
                     age_range= (15, 29), 
                     area= 'India')
india_pop_stats
# Out:
# 'In 2000, there were 139,428,253 females aged 15 to 29 living in India.'

# %%
pakistan_pop_stats = format_population_stats_sentence(year= 2000, 
                     sex= 'total', 
                     age_range= (15, 29), 
                     area= 'Pakistan')
pakistan_pop_stats

# %% [markdown]
# <h1> [A] Unit tests </h1>

# %%
def test_func():
# Out:
#   Cell In[57], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
# running the unit tests
test_func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 # running the unit tests
# ----> 2 test_func()
#
# NameError: name 'test_func' is not defined

# %% [markdown]
# <h1> [B] Population Pyramids </h1>
